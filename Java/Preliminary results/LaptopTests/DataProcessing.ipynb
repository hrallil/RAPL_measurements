# %% [markdown]
# The name column in the CSV should have the name of the test algorithm or what ever
# followed by the size of the array tested on.
#
#     Example: "merge-sort10000"
#
# NO spaces in the CSV:
#
#     Example: merge-sort10000,8.603332519531250000,7.480468750000000000,,,892.347
#
#     NOT:     merge-sort10000 ; 8.603332519531250000 , 7.480468750000000000 , , , 892.347
#
# Then simply name your cell:
#
#     print("Merge sort Data 10000 - 100000")
#
# Diffine the sizes of your arrays:
#
#     sizes = [i*10000 for i in range(1,11)]
#
# Calculate mean time for each array:
#
#     s = meanTimePrDataSize(df, "name", sizes)
#
# And plot the graphs:
#
#     showGraphs(df, s)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#load CSV
pc12 = pd.read_csv("pcTest-12.csv")
pc16 = pd.read_csv("pcTest-16.csv")
pc22 = pd.read_csv("pcTest-22.csv")
pc23 = pd.read_csv("pcTest-23.csv")
pc27 = pd.read_csv("pcTest-27.csv")
# pc 25 didnt want to pull the git repo

pc12.columns = ["Name","PKG","CPU", "GPU" , "DRAM?" , "Time (sec)"]
pc16.columns = ["Name","PKG","CPU", "GPU" , "DRAM?" , "Time (sec)"]
pc22.columns = ["Name","PKG","CPU", "GPU" , "DRAM?" , "Time (sec)"]
pc23.columns = ["Name","PKG","CPU", "GPU" , "DRAM?" , "Time (sec)"]
pc27.columns = ["Name","PKG","CPU", "GPU" , "DRAM?" , "Time (sec)"]

# delete any value < 0
pc12 = pc12[pc12['CPU'] >= 0]
pc16 = pc16[pc12['CPU'] >= 0]
pc22 = pc22[pc12['CPU'] >= 0]
pc23 = pc23[pc12['CPU'] >= 0]
pc27 = pc27[pc27['CPU'] >= 0]

#plot data
plt.plot(pc12["CPU"], ".",label="pc12")
plt.plot(pc16["CPU"], ".",label="pc16")
plt.plot(pc22["CPU"], ".",label="pc22")
plt.plot(pc23["CPU"], ".",label="pc23")
plt.plot(pc27["CPU"], ".",label="pc27")

plt.legend(loc="upper left")
plt.xlabel("test number")
plt.ylabel("CPU (J)")
plt.title("all measurements")
plt.show()
