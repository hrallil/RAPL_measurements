# %% [markdown]
# # Data analysis for all data collected during our project

# %% [markdown]
# #### imports and  loading Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

dfCounting = pd.read_csv("Results16/countingSort-PC16.csv")
dfCounting.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]

dfQuickSort = pd.read_csv("Results16/quickSort-PC16.csv")
dfQuickSort.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]

dfBubbleSort = pd.read_csv("Results16/bubbleSort-PC16.csv")
dfBubbleSort.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]

dfMergeSort = pd.read_csv("Results16/mergeSort-PC16.csv")
dfMergeSort.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]

dfReadCSV = pd.read_csv("Results16/readCSV-PC16.csv")
dfReadCSV.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]

# %% [markdown]
# #### Moving information from Test name to a seperate column

# %%
#input type
l = []
for i in range(len(dfCounting)):
    l.append(dfCounting.iloc[i]["Test name"].split("-")[0])

dfCounting["Input case"] = l


l = []
for i in range(len(dfQuickSort)):
    l.append(dfQuickSort.iloc[i]["Test name"].split("-")[0])

dfQuickSort["Input case"] = l



l = []
for i in range(len(dfBubbleSort)):
    l.append(dfBubbleSort.iloc[i]["Test name"].split("-")[0])

dfBubbleSort["Input case"] = l


l = []
for i in range(len(dfMergeSort)):
    l.append(dfMergeSort.iloc[i]["Test name"].split("-")[0])

dfMergeSort["Input case"] = l

# %%
#input size
l = []
for i in range(len(dfCounting)):
    l.append(dfCounting.iloc[i]["Test name"].split("-")[1])

dfCounting["Size"] = l


l = []
for i in range(len(dfQuickSort)):
    l.append(dfQuickSort.iloc[i]["Test name"].split("-")[1])

dfQuickSort["Size"] = l



l = []
for i in range(len(dfBubbleSort)):
    l.append(dfBubbleSort.iloc[i]["Test name"].split("-")[1])

dfBubbleSort["Size"] = l


l = []
for i in range(len(dfMergeSort)):
    l.append(dfMergeSort.iloc[i]["Test name"].split("-")[1])

dfMergeSort["Size"] = l


l = []
for i in range(len(dfReadCSV)):
    l.append(dfReadCSV.iloc[i]["Test name"].split("d")[-1])

dfReadCSV["Size"] = l

# %%
#removing values that are nonsense 
dfCounting = dfCounting[dfCounting['PKG (J)'] >= 0]
dfCounting = dfCounting[dfCounting['CPU (J)'] >= 0]
#df = df[df['Memory (byte)'] >= 0]
#df = df[df['Temperature'] >= 0]
dfCounting = dfCounting[dfCounting['Time (ms)'] >= 0]

dfCounting = dfCounting.replace("  ", np.nan)

#missing values for each column
print("MISSING DATA: \n\n ", dfCounting.isnull().sum(axis=0))

dfReadCSV["Time (ms)"].sum()/1000/60/60
# Out:
# MISSING DATA:
#
#   Test name          0
# PKG (J)            0
# CPU (J)            0
# GPU (J)        20799
# Memory (J)         0
# Temperature        0
# Time (ms)          0
# Input case         0
# Size               0
# dtype: int64
# 5.783314213333333

# %% [markdown]
# #### Removing ourliers

# %% [markdown]
# #### Subtract readCSV from data

# %%
#Counting sort
bgAVGrand = []
bgAVGWorst = []
bgAVGBest = []
s = [25000,50000,75000,100000,200000,300000,400000,500000,600000,700000,800000,900000,1000000]
l = []
for size in range(len(s)):
    bgAVGrand.append(dfReadCSV[dfReadCSV["Test name"] == f"readCSVCountingRand{s[size]}"].mean())

for size in range(len(s)):
    bgAVGWorst.append(dfReadCSV[dfReadCSV["Test name"] == f"readCSVCountingBest{s[size]}"].mean())

for size in range(len(s)):
    bgAVGBest.append(dfReadCSV[dfReadCSV["Test name"] == f"readCSVCountingWorst{s[size]}"].mean())

for i in range(len(dfCounting)):
    for size in range(len(s)):
        if (int(dfCounting["Size"][i]) == s[size]):
            if(dfCounting["Input case"][i] != "worst" and dfCounting["Input case"][i] != "best"):
                l.append(dfCounting["CPU (J)"][i] - bgAVGrand[size]["CPU (J)"])
            if(dfCounting["Input case"][i] == "best"):
                l.append(dfCounting["CPU (J)"][i] - bgAVGBest[size]["CPU (J)"])                                         
            if(dfCounting["Input case"][i] == "worst"):
                l.append(dfCounting["CPU (J)"][i] - bgAVGWorst[size]["CPU (J)"])                               

dfCounting["CPU - BG"] = l
dfCounting[dfCounting["Input case"] == "best"]
# Out:
#             Test name   PKG (J)   CPU (J)  GPU (J)  Memory (J)  Temperature  \
# 10399    best-25000-1  1.878296  1.601929      NaN    0.118958           62
# 10400    best-25000-1  1.876892  1.619263      NaN    0.113342           62
# 10401    best-25000-1  1.891479  1.635620      NaN    0.111633           62
# 10402    best-25000-1  1.797913  1.523071      NaN    0.118103           62
# 10403    best-25000-1  1.755127  1.432678      NaN    0.127747           62
# ...               ...       ...       ...      ...         ...          ...
# 15594  best-1000000-1  6.719788  5.797974      NaN    0.380432           71
# 15595  best-1000000-1  6.539246  5.623535      NaN    0.380737           71
# 15596  best-1000000-1  6.512512  5.608704      NaN    0.366638           71
# 15597  best-1000000-1  6.630493  5.714172      NaN    0.381470           70
# 15598  best-1000000-1  6.861755  5.932434      NaN    0.407776           70
#
#        Time (ms) Input case     Size  CPU - BG
# 10399    223.673       best    25000       NaN
# 10400    195.949       best    25000       NaN
# 10401    196.755       best    25000       NaN
# 10402    216.795       best    25000       NaN
# 10403    281.388       best    25000       NaN
# ...          ...        ...      ...       ...
# 15594    713.453       best  1000000       NaN
# 15595    725.147       best  1000000       NaN
# 15596    724.385       best  1000000       NaN
# 15597    707.163       best  1000000       NaN
# 15598    741.815       best  1000000       NaN
#
# [5200 rows x 10 columns]

# %%
#Bubblesort
bgAVGbubbleRand = []
s = [25000,50000,75000,100000,200000,300000,400000,500000,600000,700000,800000,900000,1000000]
l = []
for size in range(len(s)):
    bgAVGbubbleRand.append(dfReadCSV[dfReadCSV["Test name"] == f"readCSVRand{s[size]}"].mean())

for i in range(len(dfBubbleSort)):
    for size in range(len(s)):
        if (int(dfBubbleSort["Size"][i]) == s[size]):
            if(dfBubbleSort["Input case"][i] != "worst" and dfBubbleSort["Input case"][i] != "best"):
                l.append(dfBubbleSort["CPU (J)"][i] - bgAVGbubbleRand[size]["CPU (J)"])
            if(dfBubbleSort["Input case"][i] == "best"):
                l.append(0)                                         # We're missing sorted. Has been named "revsorted" in the Makefile for readCSV
            if(dfBubbleSort["Input case"][i] == "worst"):
                l.append(0)                                         # we need to redo rev-sorted. has been mixed with revsorted in the Makefile for readCSV

dfBubbleSort["CPU - BG"] = l

dfBubbleSort
# Out:
#              Test name     PKG (J)     CPU (J) GPU (J)  Memory (J)  \
# 0      random1-25000-1   13.232300   11.544128            0.399902
# 1      random1-25000-1   14.163696   12.361511            0.493103
# 2      random1-25000-1   13.530029   11.768127            0.451172
# 3      random1-25000-1   14.085632   12.302307            0.486084
# 4      random1-25000-1   14.142822   12.376465            0.485718
# ...                ...         ...         ...     ...         ...
# 11755   worst-500000-1  815.602600  719.116455           18.233643
# 11756   worst-500000-1  806.500366  709.628906           19.146301
# 11757   worst-500000-1  808.787598  712.215637           18.715515
# 11758   worst-500000-1  810.676819  712.063965           20.324219
# 11759   worst-500000-1  804.544067  707.847473           18.875793
#
#        Temperature  Time (ms) Input case    Size  CPU - BG
# 0               69    1710.16    random1   25000       NaN
# 1               69    1723.56    random1   25000       NaN
# 2               69    1730.49    random1   25000       NaN
# 3               70    1704.74    random1   25000       NaN
# 4               70    1699.14    random1   25000       NaN
# ...            ...        ...        ...     ...       ...
# 11755           64  107186.00      worst  500000       0.0
# 11756           57  107578.00      worst  500000       0.0
# 11757           63  107361.00      worst  500000       0.0
# 11758           57  108984.00      worst  500000       0.0
# 11759           56  107400.00      worst  500000       0.0
#
# [11760 rows x 10 columns]

# %%
#Mergesort
bgAVGrand = []
bgAVGWorst = []
bgAVGBest = []
s = [25000,50000,75000,100000,200000,300000,400000,500000,600000,700000,800000,900000,1000000]
l = []
for size in range(len(s)):
    bgAVGrand.append(dfReadCSV[dfReadCSV["Test name"] == f"readCSVRand{s[size]}"].mean())
for size in range(len(s)):
    bgAVGWorst.append(dfReadCSV[dfReadCSV["Test name"] == f"readCSVMergeWorst{s[size]}"].mean())
for size in range(len(s)):
    bgAVGBest.append(dfReadCSV[dfReadCSV["Test name"] == f"readCSVMergeBest{s[size]}"].mean())

for i in range(len(dfMergeSort)):
    for size in range(len(s)):
        if (int(dfMergeSort["Size"][i]) == s[size]):
            if(dfMergeSort["Input case"][i] != "worst" and dfMergeSort["Input case"][i] != "best"):
                l.append(dfMergeSort["CPU (J)"][i] - bgAVGrand[size]["CPU (J)"])
            if(dfMergeSort["Input case"][i] == "best"):
                l.append(0)                                         # We're missing sorted. Has been named "revsorted" in the Makefile for readCSV
            if(dfMergeSort["Input case"][i] == "worst"):
                l.append(dfMergeSort["CPU (J)"][i] - bgAVGWorst[size]["CPU (J)"])                                         # we need to redo rev-sorted. has been mixed with revsorted in the Makefile for readCSV

dfMergeSort["CPU - BG"] = l

dfMergeSort[dfMergeSort["Input case"]=="best"]
# Out:
#             Test name   PKG (J)   CPU (J) GPU (J)  Memory (J)  Temperature  \
# 6399     best-25000-1  2.144348  1.843567            0.133606           72
# 6400     best-25000-1  2.076294  1.757446            0.127869           72
# 6401     best-25000-1  2.113647  1.822815            0.119995           72
# 6402     best-25000-1  2.221313  1.927490            0.131714           72
# 6403     best-25000-1  2.150085  1.861267            0.121155           72
# ...               ...       ...       ...     ...         ...          ...
# 11594  best-1000000-1  7.467285  6.437561            0.411072           72
# 11595  best-1000000-1  8.039001  6.894043            0.473633           72
# 11596  best-1000000-1  7.963867  6.857239            0.462646           71
# 11597  best-1000000-1  8.168213  7.050232            0.470093           71
# 11598  best-1000000-1  8.557922  7.393311            0.499573           71
#
#        Time (ms) Input case     Size  CPU - BG
# 6399     209.112       best    25000       0.0
# 6400     241.316       best    25000       0.0
# 6401     212.796       best    25000       0.0
# 6402     214.291       best    25000       0.0
# 6403     212.584       best    25000       0.0
# ...          ...        ...      ...       ...
# 11594    805.561       best  1000000       0.0
# 11595    861.733       best  1000000       0.0
# 11596    828.897       best  1000000       0.0
# 11597    841.059       best  1000000       0.0
# 11598    869.967       best  1000000       0.0
#
# [5200 rows x 10 columns]

# %%
#Quicksort
bgAVGrand = []
bgAVGWorst = []
bgAVGBest = []
s = [25000,50000,75000,100000,200000,300000,400000,500000,600000,700000,800000,900000,1000000]
l = []
for size in range(len(s)):
    bgAVGrand.append(dfReadCSV[dfReadCSV["Test name"] == f"readCSVRand{s[size]}"].mean())
for size in range(len(s)):
    bgAVGWorst.append(dfReadCSV[dfReadCSV["Test name"] == f"readCSVMergeWorst{s[size]}"].mean())
for size in range(len(s)):
    bgAVGBest.append(dfReadCSV[dfReadCSV["Test name"] == f"readCSVQuickBest{s[size]}"].mean())

for i in range(len(dfQuickSort)):
    for size in range(len(s)):
        if (int(dfQuickSort["Size"][i]) == s[size]):
            if(dfQuickSort["Input case"][i] != "worst" and dfQuickSort["Input case"][i] != "best"):
                l.append(dfQuickSort["CPU (J)"][i] - bgAVGrand[size]["CPU (J)"])
            if(dfQuickSort["Input case"][i] == "best"):
                l.append(dfQuickSort["CPU (J)"][i] - bgAVGBest[size]["CPU (J)"])                                         
            if(dfQuickSort["Input case"][i] == "worst"):
                l.append(0)                                         # we need to redo rev-sorted. has been mixed with revsorted in the Makefile for readCSV

dfQuickSort["CPU - BG"] = l

# %% [markdown]
# ## PLOTS

# %% [markdown]
# #### Basic plots (raw data vs size/time)

# %%
plt.figure(figsize=(10,7))
plt.title("countingsort data")
sns.violinplot(data = dfCounting, y = "CPU (J)", x = "Size", hue = "Input case")
# Out:
# <AxesSubplot:title={'center':'countingsort data'}, xlabel='Size', ylabel='CPU (J)'>

# %%
plt.figure(figsize=(10,7))
plt.title("Quicksort data")
sns.violinplot(data = dfQuickSort[dfQuickSort["Input case"] != "worst"], y = "Time (ms)", x = "Size", hue ="Input case")
# Out:
# <AxesSubplot:title={'center':'Quicksort data'}, xlabel='Size', ylabel='Time (ms)'>

# %%
plt.figure(figsize=(10,7))
plt.title("Bubblesort data")
sns.violinplot(data = dfBubbleSort, y = "Time (ms)", x = "Size", hue ="Input case")
# Out:
# <AxesSubplot:title={'center':'Bubblesort data'}, xlabel='Size', ylabel='Time (ms)'>

# %%
plt.figure(figsize=(10,7))
plt.title("Mergesort data")
sns.violinplot(data = dfMergeSort[dfMergeSort["Size"] == "1000000"], y = "Time (ms)", x = "Size", hue ="Input case")
# Out:
# <AxesSubplot:title={'center':'Mergesort data'}, xlabel='Size', ylabel='Time (ms)'>

# %% [markdown]
# ## ReadCSV subtracted from data PLOTS

# %%
plt.figure(figsize=(10,7))
plt.title("countingsort data") # [dfCounting["Input case"]!="best"][dfCounting["Input case"]!="worst"]
sns.violinplot(data = dfCounting, y = "CPU - BG", x = "Size", hue = "Input case")
# Out:
# <AxesSubplot:title={'center':'countingsort data'}, xlabel='Size', ylabel='CPU - BG'>

# %%
plt.figure(figsize=(10,7))
plt.title("Mergesort data") # [dfCounting["Input case"]!="best"][dfCounting["Input case"]!="worst"]
sns.violinplot(data = dfMergeSort, y = "CPU - BG", x = "Size", hue = "Input case")
# Out:
# <AxesSubplot:title={'center':'Mergesort data'}, xlabel='Size', ylabel='CPU - BG'>

# %%
plt.figure(figsize=(10,7))
plt.title("Mergesort data") # [dfCounting["Input case"]!="best"][dfCounting["Input case"]!="worst"]
sns.violinplot(data = dfQuickSort, y = "CPU - BG", x = "Size", hue = "Input case")
# Out:
# <AxesSubplot:title={'center':'Mergesort data'}, xlabel='Size', ylabel='CPU - BG'>

# %%
plt.figure(figsize=(10,7))
plt.title("Mergesort data") # [dfCounting["Input case"]!="best"][dfCounting["Input case"]!="worst"]
sns.violinplot(data = dfBubbleSort, y = "CPU - BG", x = "Size", hue = "Input case")
# Out:
# <AxesSubplot:title={'center':'Mergesort data'}, xlabel='Size', ylabel='CPU - BG'>

# %% [markdown]
# ## AVG for each computer

# %% [markdown]
# #### Quicksort

# %%
quick16 = pd.read_csv("Results16/quickSort-PC16.csv")
quick16.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]
quick21 = pd.read_csv("Results21/quickSort-PC21.csv")
quick21.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]
quick23 = pd.read_csv("Results23/quickSort-PC23.csv") 
quick23.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]
quick6 = pd.read_csv("Results6/quickSort-PC6.csv")
quick6.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]


readCSV16 = pd.read_csv("Results16/readCSV-PC16.csv")
readCSV16.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]
readCSV6 = pd.read_csv("Results6/readCSV-PC6.csv")
readCSV6.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]
readCSV21 = pd.read_csv("Results21/readCSV-PC21.csv")
readCSV21.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]
readCSV23 = pd.read_csv("Results23/readCSV-PC23.csv")
readCSV23.columns=["Test name","PKG (J)","CPU (J)","GPU (J)","Memory (J)","Temperature","Time (ms)"]

# %%
def removeNonsense(df):
    df = df[df["PKG (J)"]>=0]
    df = df[df["CPU (J)"]>=0]
    df = df[df["Time (ms)"]>=0]
    return df

quick21 = removeNonsense(quick21)
quick16 = removeNonsense(quick16)
quick23 = removeNonsense(quick23)
quick6 = removeNonsense(quick6)


readCSV21 = removeNonsense(readCSV21)
readCSV16 = removeNonsense(readCSV16)
readCSV23 = removeNonsense(readCSV23)
readCSV6 = removeNonsense(readCSV6)
readCSV16
# Out:
#                     Test name   PKG (J)   CPU (J) GPU (J)  Memory (J)  \
# 0       readCSV-Random1-25000  2.240601  1.966187            0.134399
# 1       readCSV-Random1-25000  2.062317  1.775085            0.126160
# 2       readCSV-Random1-25000  2.140869  1.876709            0.121887
# 3       readCSV-Random1-25000  2.217102  1.940735            0.133545
# 4       readCSV-Random1-25000  2.058533  1.796814            0.119385
# ...                       ...       ...       ...     ...         ...
# 41594  readCSV-Sorted-1000000  7.584045  6.620728            0.382446
# 41595  readCSV-Sorted-1000000  7.647522  6.666382            0.386780
# 41596  readCSV-Sorted-1000000  7.715393  6.740112            0.386230
# 41597  readCSV-Sorted-1000000  7.573486  6.611694            0.383301
# 41598  readCSV-Sorted-1000000  7.495056  6.534302            0.386780
#
#        Temperature  Time (ms)
# 0               53    227.880
# 1               53    250.212
# 2               53    222.526
# 3               53    226.620
# 4               53    219.516
# ...            ...        ...
# 41594           69    805.509
# 41595           69    817.192
# 41596           70    828.109
# 41597           70    816.762
# 41598           71    784.613
#
# [41599 rows x 7 columns]

# %%
def makeinputColumn(df):
    l = []
    for i in range(len(df)):
        l.append(df.iloc[i]["Test name"].split("-")[0])

    df["Input case"] = l
makeinputColumn(quick21)
makeinputColumn(quick23)
makeinputColumn(quick6)
makeinputColumn(quick16)
print(quick21)

def makeinputColumn_readCSV(df):
    l = []
    for i in range(len(df)):
        l.append(df.iloc[i]["Test name"].split("-")[1].lower())
    df["Input case"] = l
    
makeinputColumn_readCSV(readCSV16)
makeinputColumn_readCSV(readCSV21)
makeinputColumn_readCSV(readCSV23)
makeinputColumn_readCSV(readCSV6)
# Out:
#              Test name   PKG (J)   CPU (J) GPU (J)  Memory (J)  Temperature  \
# 0      random1-25000-1  2.153381  1.893677            0.124512           29
# 1      random1-25000-1  2.171021  1.890686            0.123047           29
# 2      random1-25000-1  2.138184  1.884949            0.119690           29
# 3      random1-25000-1  2.313232  2.037598            0.137939           29
# 4      random1-25000-1  2.163818  1.899353            0.129150           29
# ...                ...       ...       ...     ...         ...          ...
# 14073   best-1000000-1  7.644104  6.685913            0.410217           64
# 14074   best-1000000-1  7.567322  6.655640            0.413513           64
# 14075   best-1000000-1  7.379944  6.455933            0.386841           64
# 14076   best-1000000-1  7.692749  6.727966            0.417664           65
# 14077   best-1000000-1  7.254028  6.377808            0.378906           65
#
#        Time (ms) Input case     Size
# 0        220.583    random1    25000
# 1        223.840    random1    25000
# 2        213.484    random1    25000
# 3        223.535    random1    25000
# 4        222.574    random1    25000
# ...          ...        ...      ...
# 14073    774.068       best  1000000
# 14074    739.080       best  1000000
# 14075    766.003       best  1000000
# 14076    762.062       best  1000000
# 14077    737.696       best  1000000
#
# [14070 rows x 9 columns]

# %%
def makeSizecolumn(df):
    l = []
    for i in range(len(df)):
        l.append(int(df.iloc[i]["Test name"].split("-")[1]))

    df["Size"] = l
makeSizecolumn(quick21)
makeSizecolumn(quick23)
makeSizecolumn(quick6)
makeSizecolumn(quick16)

def makeSizecolumn_readCSV(df):
    l = []
    for i in range(len(df)):
        l.append(int(df.iloc[i]["Test name"].split("-")[-1]))

    df["Size"] = l

makeSizecolumn_readCSV(readCSV16)
makeSizecolumn_readCSV(readCSV21)
makeSizecolumn_readCSV(readCSV23)
makeSizecolumn_readCSV(readCSV6)

# %%
quick16
# Out:
#              Test name   PKG (J)   CPU (J) GPU (J)  Memory (J)  Temperature  \
# 0      random1-25000-1  1.962158  1.692078            0.127014           34
# 1      random1-25000-1  2.023621  1.674500            0.149536           34
# 2      random1-25000-1  2.120483  1.841614            0.138977           34
# 3      random1-25000-1  2.118164  1.841858            0.134216           34
# 4      random1-25000-1  2.049316  1.782532            0.127319           34
# ...                ...       ...       ...     ...         ...          ...
# 14073   best-1000000-1  7.147827  6.179016            0.391418           68
# 14074   best-1000000-1  7.349426  6.347900            0.425720           68
# 14075   best-1000000-1  7.313232  6.347717            0.419617           68
# 14076   best-1000000-1  7.535034  6.532166            0.428528           68
# 14077   best-1000000-1  7.502014  6.471680            0.431274           67
#
#        Time (ms) Input case     Size
# 0        229.315    random1    25000
# 1        328.975    random1    25000
# 2        228.547    random1    25000
# 3        228.787    random1    25000
# 4        222.677    random1    25000
# ...          ...        ...      ...
# 14073    793.451       best  1000000
# 14074    796.630       best  1000000
# 14075    757.244       best  1000000
# 14076    792.646       best  1000000
# 14077    828.790       best  1000000
#
# [14067 rows x 9 columns]

# %% [markdown]
# ### remove outliers

# %%
def remove_outliers(df, type, size):
    q1 = df[df["Input case"] == type][df["Size"]==size]["CPU (J)"].quantile(q=0.25)
    q3 = df[df["Input case"] == type][df["Size"]==size]["CPU (J)"].quantile(q=0.75)
    IQR = q3 - q1 
    LF = q1 - 1.5* IQR
    UF = q3 + 1.5* IQR

    print(f"For size, case: {size},{type}. Lower fence: {LF} Upper fence: {UF}.")
    df = df[df["Input case"] == type][df["Size"]==size][df["CPU (J)"] <= UF]
    df = df[df["Input case"] == type][df["Size"]==size][df["CPU (J)"] >= LF]

# %%
def remove_outliers_for_pc(df):
    s = [25000,50000,75000,100000,200000,300000,400000,500000,600000,700000,800000,900000,1000000]
    c = ["best", "worst", "random1","random2","random3","random4","random5","random6","random7","random8","random9","random10",]
    for case in range(len(c)):
        for size in range(len(s)):
            remove_outliers(df, c[case], s[size])
remove_outliers_for_pc(quick16)
remove_outliers_for_pc(quick6)
remove_outliers_for_pc(quick21)
remove_outliers_for_pc(quick23)
# Out:
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\2629238994.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q1 = df[df["Input case"] == type][df["Size"]==size]["CPU (J)"].quantile(q=0.25)
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\2629238994.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q3 = df[df["Input case"] == type][df["Size"]==size]["CPU (J)"].quantile(q=0.75)
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\2629238994.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[df["Input case"] == type][df["Size"]==size][df["CPU (J)"] <= UF]
# For size, case: 25000,best. Lower fence: 1.1214447021484375 Upper fence: 1.6398773193359375.
# For size, case: 50000,best. Lower fence: 1.5760040283203125 Upper fence: 2.1419219970703125.
# For size, case: 75000,best. Lower fence: 1.9684066772460938 Upper fence: 2.7023544311523438.
# For size, case: 100000,best. Lower fence: 2.2197113037109375 Upper fence: 3.2438812255859375.
# For size, case: 200000,best. Lower fence: 3.143676757812499 Upper fence: 4.161743164062501.
# For size, case: 300000,best. Lower fence: 3.731208801269532 Upper fence: 4.32135772705078.
# For size, case: 400000,best. Lower fence: 4.167808532714844 Upper fence: 4.639060974121094.
# For size, case: 500000,best. Lower fence: 3.9255599975585938 Upper fence: 5.155357360839844.
# For size, case: 600000,best. Lower fence: 4.7434844970703125 Upper fence: 5.1977081298828125.
# For size, case: 700000,best. Lower fence: 5.037628173828125 Upper fence: 5.560089111328125.
# For size, case: 800000,best. Lower fence: 5.5001220703125 Upper fence: 5.9766845703125.
# For size, case: 900000,best. Lower fence: 5.8903350830078125 Upper fence: 6.3964385986328125.
# For size, case: 1000000,best. Lower fence: 6.019309997558594 Upper fence: 6.751426696777344.
# For size, case: 25000,worst. Lower fence: 4.722381591796875 Upper fence: 5.545013427734375.
# For size, case: 50000,worst. Lower fence: 8.572578430175781 Upper fence: 15.264289855957031.
# For size, case: 75000,worst. Lower fence: 23.107070922851562 Upper fence: 25.306900024414062.
# For size, case: 100000,worst. Lower fence: 35.05943298339844 Upper fence: 49.55931091308594.
# For size, case: 200000,worst. Lower fence: 78.59121704101562 Upper fence: 221.75674438476562.
# For size, case: 300000,worst. Lower fence: 311.1471633911133 Upper fence: 406.76282501220703.
# For size, case: 400000,worst. Lower fence: 588.32861328125 Upper fence: 620.46435546875.
# For size, case: 500000,worst. Lower fence: 904.9138488769529 Upper fence: 988.2602844238284.
# For size, case: 600000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 700000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 800000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 900000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 1000000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 25000,random1. Lower fence: 1.5850982666015625 Upper fence: 2.0354156494140625.
# For size, case: 50000,random1. Lower fence: 1.8300323486328125 Upper fence: 2.6459503173828125.
# For size, case: 75000,random1. Lower fence: 2.6203765869140625 Upper fence: 3.1600494384765625.
# For size, case: 100000,random1. Lower fence: 2.5050201416015625 Upper fence: 4.0626373291015625.
# For size, case: 200000,random1. Lower fence: 2.7747879028320312 Upper fence: 5.493110656738281.
# For size, case: 300000,random1. Lower fence: 3.714874267578125 Upper fence: 5.262847900390625.
# For size, case: 400000,random1. Lower fence: 4.460014343261719 Upper fence: 4.971427917480469.
# For size, case: 500000,random1. Lower fence: 4.817626953125 Upper fence: 5.4354248046875.
# For size, case: 600000,random1. Lower fence: 5.104484558105469 Upper fence: 6.215141296386719.
# For size, case: 700000,random1. Lower fence: 5.5531158447265625 Upper fence: 6.4793853759765625.
# For size, case: 800000,random1. Lower fence: 5.793853759765625 Upper fence: 7.622833251953125.
# For size, case: 900000,random1. Lower fence: 6.670845031738281 Upper fence: 7.288459777832031.
# For size, case: 1000000,random1. Lower fence: 7.0371093749999964 Upper fence: 7.7037353515625036.
# For size, case: 25000,random2. Lower fence: 1.6084976196289062 Upper fence: 2.1315078735351562.
# For size, case: 50000,random2. Lower fence: 1.9802322387695312 Upper fence: 2.5818557739257812.
# For size, case: 75000,random2. Lower fence: 2.334259033203125 Upper fence: 3.416778564453125.
# For size, case: 100000,random2. Lower fence: 2.4977340698242188 Upper fence: 4.122062683105469.
# For size, case: 200000,random2. Lower fence: 3.6557769775390625 Upper fence: 4.4160308837890625.
# For size, case: 300000,random2. Lower fence: 3.1107330322265625 Upper fence: 5.8755035400390625.
# For size, case: 400000,random2. Lower fence: 4.486000061035156 Upper fence: 5.325294494628906.
# For size, case: 500000,random2. Lower fence: 4.5064239501953125 Upper fence: 5.6076202392578125.
# For size, case: 600000,random2. Lower fence: 5.139839172363281 Upper fence: 5.753303527832031.
# For size, case: 700000,random2. Lower fence: 5.875312805175781 Upper fence: 6.671882629394531.
# For size, case: 800000,random2. Lower fence: 6.4270477294921875 Upper fence: 7.2803192138671875.
# For size, case: 900000,random2. Lower fence: 6.038604736328125 Upper fence: 8.477691650390625.
# For size, case: 1000000,random2. Lower fence: 6.974296569824217 Upper fence: 7.8156661987304705.
# For size, case: 25000,random3. Lower fence: 1.519256591796875 Upper fence: 2.039886474609375.
# For size, case: 50000,random3. Lower fence: 1.7865753173828125 Upper fence: 2.6913604736328125.
# For size, case: 75000,random3. Lower fence: 2.3195877075195312 Upper fence: 3.5164260864257812.
# For size, case: 100000,random3. Lower fence: 2.8080215454101562 Upper fence: 3.5837173461914062.
# For size, case: 200000,random3. Lower fence: 3.399047851562501 Upper fence: 4.333496093749999.
# For size, case: 300000,random3. Lower fence: 3.9917678833007812 Upper fence: 5.175300598144531.
# For size, case: 400000,random3. Lower fence: 3.464630126953125 Upper fence: 6.303009033203125.
# For size, case: 500000,random3. Lower fence: 4.947235107421875 Upper fence: 5.835418701171875.
# For size, case: 600000,random3. Lower fence: 5.319435119628906 Upper fence: 5.893592834472656.
# For size, case: 700000,random3. Lower fence: 5.834587097167969 Upper fence: 6.858329772949219.
# For size, case: 800000,random3. Lower fence: 6.248512268066406 Upper fence: 7.208534240722656.
# For size, case: 900000,random3. Lower fence: 6.63177490234375 Upper fence: 7.71514892578125.
# For size, case: 1000000,random3. Lower fence: 6.4472198486328125 Upper fence: 8.887161254882812.
# For size, case: 25000,random4. Lower fence: 1.5180435180664062 Upper fence: 2.1412734985351562.
# For size, case: 50000,random4. Lower fence: 2.023681640625 Upper fence: 2.778564453125.
# For size, case: 75000,random4. Lower fence: 1.9669418334960938 Upper fence: 3.6193466186523438.
# For size, case: 100000,random4. Lower fence: 2.63232421875 Upper fence: 3.90673828125.
# For size, case: 200000,random4. Lower fence: 3.5306243896484366 Upper fence: 4.655624389648438.
# For size, case: 300000,random4. Lower fence: 3.756317138671875 Upper fence: 5.424774169921875.
# For size, case: 400000,random4. Lower fence: 3.74859619140625 Upper fence: 6.21759033203125.
# For size, case: 500000,random4. Lower fence: 4.781654357910156 Upper fence: 5.705421447753906.
# For size, case: 600000,random4. Lower fence: 5.225311279296875 Upper fence: 5.998748779296875.
# For size, case: 700000,random4. Lower fence: 5.84149169921875 Upper fence: 6.61810302734375.
# For size, case: 800000,random4. Lower fence: 6.3790740966796875 Upper fence: 7.1619110107421875.
# For size, case: 900000,random4. Lower fence: 6.79229736328125 Upper fence: 7.76055908203125.
# For size, case: 1000000,random4. Lower fence: 6.351966857910156 Upper fence: 8.871192932128906.
# For size, case: 25000,random5. Lower fence: 1.74627685546875 Upper fence: 2.10394287109375.
# For size, case: 50000,random5. Lower fence: 1.847381591796875 Upper fence: 2.693328857421875.
# For size, case: 75000,random5. Lower fence: 2.4309844970703125 Upper fence: 3.3533477783203125.
# For size, case: 100000,random5. Lower fence: 2.584320068359375 Upper fence: 3.928924560546875.
# For size, case: 200000,random5. Lower fence: 3.6975860595703125 Upper fence: 4.4170684814453125.
# For size, case: 300000,random5. Lower fence: 3.82647705078125 Upper fence: 5.04644775390625.
# For size, case: 400000,random5. Lower fence: 4.333038330078125 Upper fence: 5.534576416015625.
# For size, case: 500000,random5. Lower fence: 4.672080993652344 Upper fence: 5.632591247558594.
# For size, case: 600000,random5. Lower fence: 5.026969909667969 Upper fence: 6.029960632324219.
# For size, case: 700000,random5. Lower fence: 4.993461608886719 Upper fence: 7.546867370605469.
# For size, case: 800000,random5. Lower fence: 6.071205139160156 Upper fence: 7.541847229003906.
# For size, case: 900000,random5. Lower fence: 6.634788513183594 Upper fence: 7.867149353027344.
# For size, case: 1000000,random5. Lower fence: 6.9608078002929705 Upper fence: 8.223808288574217.
# For size, case: 25000,random6. Lower fence: 1.5252532958984375 Upper fence: 2.1379241943359375.
# For size, case: 50000,random6. Lower fence: 1.895599365234375 Upper fence: 2.661102294921875.
# For size, case: 75000,random6. Lower fence: 2.1996002197265625 Upper fence: 3.3252105712890625.
# For size, case: 100000,random6. Lower fence: 2.4807205200195312 Upper fence: 3.8430862426757812.
# For size, case: 200000,random6. Lower fence: 3.715850830078125 Upper fence: 4.296417236328125.
# For size, case: 300000,random6. Lower fence: 3.994537353515625 Upper fence: 4.505767822265625.
# For size, case: 400000,random6. Lower fence: 4.272468566894531 Upper fence: 5.115180969238281.
# For size, case: 500000,random6. Lower fence: 4.804527282714844 Upper fence: 5.752220153808594.
# For size, case: 600000,random6. Lower fence: 5.27301025390625 Upper fence: 5.99578857421875.
# For size, case: 700000,random6. Lower fence: 5.859886169433594 Upper fence: 6.566123962402344.
# For size, case: 800000,random6. Lower fence: 6.423652648925781 Upper fence: 7.137458801269531.
# For size, case: 900000,random6. Lower fence: 6.6284103393554705 Upper fence: 7.744194030761717.
# For size, case: 1000000,random6. Lower fence: 6.580818176269531 Upper fence: 8.428901672363281.
# For size, case: 25000,random7. Lower fence: 1.5911178588867188 Upper fence: 2.0876388549804688.
# For size, case: 50000,random7. Lower fence: 2.0459518432617188 Upper fence: 2.5490646362304688.
# For size, case: 75000,random7. Lower fence: 1.9908828735351562 Upper fence: 3.4496841430664062.
# For size, case: 100000,random7. Lower fence: 2.7234420776367188 Upper fence: 3.8322677612304688.
# For size, case: 200000,random7. Lower fence: 3.492134094238282 Upper fence: 4.29065704345703.
# For size, case: 300000,random7. Lower fence: 3.958953857421875 Upper fence: 5.237762451171875.
# For size, case: 400000,random7. Lower fence: 3.8199615478515625 Upper fence: 6.0234527587890625.
# For size, case: 500000,random7. Lower fence: 4.637580871582031 Upper fence: 5.424995422363281.
# For size, case: 600000,random7. Lower fence: 5.0998382568359375 Upper fence: 5.7923431396484375.
# For size, case: 700000,random7. Lower fence: 5.687950134277344 Upper fence: 6.997703552246094.
# For size, case: 800000,random7. Lower fence: 5.911712646484375 Upper fence: 7.256072998046875.
# For size, case: 900000,random7. Lower fence: 6.4564056396484375 Upper fence: 7.3399505615234375.
# For size, case: 1000000,random7. Lower fence: 7.001937866210936 Upper fence: 7.876327514648439.
# For size, case: 25000,random8. Lower fence: 1.6156692504882812 Upper fence: 2.2268142700195312.
# For size, case: 50000,random8. Lower fence: 2.1356430053710938 Upper fence: 2.5443954467773438.
# For size, case: 75000,random8. Lower fence: 2.6269073486328125 Upper fence: 3.3433380126953125.
# For size, case: 100000,random8. Lower fence: 2.4522705078125 Upper fence: 3.7139892578125.
# For size, case: 200000,random8. Lower fence: 3.3839187622070312 Upper fence: 4.719429016113281.
# For size, case: 300000,random8. Lower fence: 3.9410018920898438 Upper fence: 4.534690856933594.
# For size, case: 400000,random8. Lower fence: 4.37042236328125 Upper fence: 5.43450927734375.
# For size, case: 500000,random8. Lower fence: 4.737762451171875 Upper fence: 5.320770263671875.
# For size, case: 600000,random8. Lower fence: 4.91436767578125 Upper fence: 6.06939697265625.
# For size, case: 700000,random8. Lower fence: 5.865684509277344 Upper fence: 6.380393981933594.
# For size, case: 800000,random8. Lower fence: 5.371543884277344 Upper fence: 8.068992614746094.
# For size, case: 900000,random8. Lower fence: 6.8591156005859375 Upper fence: 7.4881439208984375.
# For size, case: 1000000,random8. Lower fence: 7.056159973144531 Upper fence: 7.826362609863281.
# For size, case: 25000,random9. Lower fence: 1.5575408935546875 Upper fence: 2.1376190185546875.
# For size, case: 50000,random9. Lower fence: 2.0346145629882812 Upper fence: 2.8176345825195312.
# For size, case: 75000,random9. Lower fence: 2.51763916015625 Upper fence: 3.43682861328125.
# For size, case: 100000,random9. Lower fence: 2.5712661743164062 Upper fence: 3.9256973266601562.
# For size, case: 200000,random9. Lower fence: 3.7227325439453125 Upper fence: 4.3174591064453125.
# For size, case: 300000,random9. Lower fence: 3.8736038208007812 Upper fence: 5.104133605957031.
# For size, case: 400000,random9. Lower fence: 4.4469757080078125 Upper fence: 5.1923370361328125.
# For size, case: 500000,random9. Lower fence: 4.660919189453125 Upper fence: 5.539703369140625.
# For size, case: 600000,random9. Lower fence: 5.164283752441406 Upper fence: 5.770423889160156.
# For size, case: 700000,random9. Lower fence: 5.436553955078125 Upper fence: 6.819610595703125.
# For size, case: 800000,random9. Lower fence: 6.2218170166015625 Upper fence: 7.1584625244140625.
# For size, case: 900000,random9. Lower fence: 6.713706970214844 Upper fence: 7.983543395996094.
# For size, case: 1000000,random9. Lower fence: 6.526092529296875 Upper fence: 8.725189208984375.
# For size, case: 25000,random10. Lower fence: 1.5602874755859375 Upper fence: 2.1595306396484375.
# For size, case: 50000,random10. Lower fence: 2.085723876953125 Upper fence: 2.694732666015625.
# For size, case: 75000,random10. Lower fence: 2.284210205078125 Upper fence: 3.478057861328125.
# For size, case: 100000,random10. Lower fence: 2.587127685546875 Upper fence: 3.951751708984375.
# For size, case: 200000,random10. Lower fence: 3.454994201660157 Upper fence: 4.632789611816405.
# For size, case: 300000,random10. Lower fence: 3.9083633422851562 Upper fence: 4.570289611816406.
# For size, case: 400000,random10. Lower fence: 4.3391876220703125 Upper fence: 5.0008087158203125.
# For size, case: 500000,random10. Lower fence: 4.751495361328125 Upper fence: 5.954620361328125.
# For size, case: 600000,random10. Lower fence: 5.1188201904296875 Upper fence: 6.4006805419921875.
# For size, case: 700000,random10. Lower fence: 5.7067718505859375 Upper fence: 6.4715423583984375.
# For size, case: 800000,random10. Lower fence: 5.773170471191406 Upper fence: 7.443763732910156.
# For size, case: 900000,random10. Lower fence: 6.833869934082031 Upper fence: 7.605049133300781.
# For size, case: 1000000,random10. Lower fence: 7.160057067871094 Upper fence: 7.641929626464844.
# For size, case: 25000,best. Lower fence: 1.117462158203125 Upper fence: 1.585601806640625.
# For size, case: 50000,best. Lower fence: 1.6412200927734375 Upper fence: 2.0301361083984375.
# For size, case: 75000,best. Lower fence: 2.0265426635742188 Upper fence: 2.5530929565429688.
# For size, case: 100000,best. Lower fence: 2.2686691284179688 Upper fence: 3.0706100463867188.
# For size, case: 200000,best. Lower fence: 3.0777587890625 Upper fence: 3.995361328125.
# For size, case: 300000,best. Lower fence: 3.5375137329101554 Upper fence: 4.173316955566407.
# For size, case: 400000,best. Lower fence: 3.982818603515625 Upper fence: 4.481719970703125.
# For size, case: 500000,best. Lower fence: 3.787322998046875 Upper fence: 4.970062255859375.
# For size, case: 600000,best. Lower fence: 4.5226898193359375 Upper fence: 4.9979095458984375.
# For size, case: 700000,best. Lower fence: 4.8162078857421875 Upper fence: 5.3498992919921875.
# For size, case: 800000,best. Lower fence: 5.243095397949219 Upper fence: 5.779411315917969.
# For size, case: 900000,best. Lower fence: 5.6558837890625 Upper fence: 6.176025390625.
# For size, case: 1000000,best. Lower fence: 5.591041564941406 Upper fence: 6.663490295410156.
# For size, case: 25000,worst. Lower fence: 4.529762268066406 Upper fence: 5.317054748535156.
# For size, case: 50000,worst. Lower fence: 8.798881530761719 Upper fence: 14.501579284667969.
# For size, case: 75000,worst. Lower fence: 22.514350891113278 Upper fence: 24.364753723144528.
# For size, case: 100000,worst. Lower fence: 34.232017517089844 Upper fence: 47.761863708496094.
# For size, case: 200000,worst. Lower fence: 74.23204040527347 Upper fence: 215.7794036865234.
# For size, case: 300000,worst. Lower fence: 299.7696990966797 Upper fence: 391.5276336669922.
# For size, case: 400000,worst. Lower fence: 564.1059875488281 Upper fence: 601.4553527832031.
# For size, case: 500000,worst. Lower fence: 881.0900039672849 Upper fence: 946.6297378540041.
# For size, case: 600000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 700000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 800000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 900000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 1000000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 25000,random1. Lower fence: 1.5098114013671875 Upper fence: 1.9716033935546875.
# For size, case: 50000,random1. Lower fence: 1.7431640625 Upper fence: 2.512451171875.
# For size, case: 75000,random1. Lower fence: 2.4822006225585938 Upper fence: 3.0431747436523438.
# For size, case: 100000,random1. Lower fence: 2.5196380615234375 Upper fence: 3.6990814208984375.
# For size, case: 200000,random1. Lower fence: 3.1656646728515625 Upper fence: 4.1765289306640625.
# For size, case: 300000,random1. Lower fence: 3.7942047119140625 Upper fence: 4.8874664306640625.
# For size, case: 400000,random1. Lower fence: 4.2518310546875 Upper fence: 4.710205078125.
# For size, case: 500000,random1. Lower fence: 4.4280853271484375 Upper fence: 5.3292083740234375.
# For size, case: 600000,random1. Lower fence: 4.538543701171875 Upper fence: 6.362152099609375.
# For size, case: 700000,random1. Lower fence: 5.359039306640625 Upper fence: 6.077056884765625.
# For size, case: 800000,random1. Lower fence: 5.560966491699219 Upper fence: 7.068351745605469.
# For size, case: 900000,random1. Lower fence: 6.3271026611328125 Upper fence: 7.0484161376953125.
# For size, case: 1000000,random1. Lower fence: 6.6464080810546875 Upper fence: 7.5458221435546875.
# For size, case: 25000,random2. Lower fence: 1.5889968872070312 Upper fence: 2.0087356567382812.
# For size, case: 50000,random2. Lower fence: 1.8384552001953125 Upper fence: 2.4883575439453125.
# For size, case: 75000,random2. Lower fence: 2.4358291625976562 Upper fence: 3.1493911743164062.
# For size, case: 100000,random2. Lower fence: 2.4712753295898438 Upper fence: 3.8600082397460938.
# For size, case: 200000,random2. Lower fence: 3.33648681640625 Upper fence: 4.43084716796875.
# For size, case: 300000,random2. Lower fence: 2.9839019775390625 Upper fence: 5.5551910400390625.
# For size, case: 400000,random2. Lower fence: 4.193031311035156 Upper fence: 5.071754455566406.
# For size, case: 500000,random2. Lower fence: 4.4719390869140625 Upper fence: 5.1877593994140625.
# For size, case: 600000,random2. Lower fence: 4.882057189941406 Upper fence: 5.436927795410156.
# For size, case: 700000,random2. Lower fence: 5.3632965087890625 Upper fence: 6.4928131103515625.
# For size, case: 800000,random2. Lower fence: 6.060157775878906 Upper fence: 7.038002014160156.
# For size, case: 900000,random2. Lower fence: 5.799346923828125 Upper fence: 8.248809814453125.
# For size, case: 1000000,random2. Lower fence: 6.424232482910156 Upper fence: 8.047828674316406.
# For size, case: 25000,random3. Lower fence: 1.3658218383789062 Upper fence: 2.0704727172851562.
# For size, case: 50000,random3. Lower fence: 1.698974609375 Upper fence: 2.589111328125.
# For size, case: 75000,random3. Lower fence: 2.265167236328125 Upper fence: 3.294586181640625.
# For size, case: 100000,random3. Lower fence: 2.4150009155273438 Upper fence: 3.8281478881835938.
# For size, case: 200000,random3. Lower fence: 2.689666748046875 Upper fence: 5.079681396484375.
# For size, case: 300000,random3. Lower fence: 3.798614501953125 Upper fence: 4.873565673828125.
# For size, case: 400000,random3. Lower fence: 3.353973388671875 Upper fence: 6.027679443359375.
# For size, case: 500000,random3. Lower fence: 4.4556884765625 Upper fence: 5.58154296875.
# For size, case: 600000,random3. Lower fence: 5.004081726074219 Upper fence: 5.804435729980469.
# For size, case: 700000,random3. Lower fence: 5.382209777832031 Upper fence: 6.757759094238281.
# For size, case: 800000,random3. Lower fence: 6.022911071777344 Upper fence: 6.919700622558594.
# For size, case: 900000,random3. Lower fence: 6.306922912597656 Upper fence: 7.443702697753906.
# For size, case: 1000000,random3. Lower fence: 6.167716979980469 Upper fence: 8.561454772949219.
# For size, case: 25000,random4. Lower fence: 1.4335479736328125 Upper fence: 2.0215606689453125.
# For size, case: 50000,random4. Lower fence: 1.9158477783203125 Upper fence: 2.6521759033203125.
# For size, case: 75000,random4. Lower fence: 2.1438064575195312 Upper fence: 3.2143020629882812.
# For size, case: 100000,random4. Lower fence: 2.5948486328125 Upper fence: 3.819091796875.
# For size, case: 200000,random4. Lower fence: 3.2322158813476562 Upper fence: 4.588844299316406.
# For size, case: 300000,random4. Lower fence: 3.7644424438476562 Upper fence: 4.819923400878906.
# For size, case: 400000,random4. Lower fence: 4.179420471191406 Upper fence: 4.786048889160156.
# For size, case: 500000,random4. Lower fence: 4.709159851074219 Upper fence: 5.233146667480469.
# For size, case: 600000,random4. Lower fence: 4.870597839355469 Upper fence: 5.930717468261719.
# For size, case: 700000,random4. Lower fence: 5.6380615234375 Upper fence: 6.1812744140625.
# For size, case: 800000,random4. Lower fence: 6.0681304931640625 Upper fence: 6.8946685791015625.
# For size, case: 900000,random4. Lower fence: 6.229454040527344 Upper fence: 7.720359802246094.
# For size, case: 1000000,random4. Lower fence: 6.415351867675781 Upper fence: 7.796150207519531.
# For size, case: 25000,random5. Lower fence: 1.6036605834960938 Upper fence: 2.0367050170898438.
# For size, case: 50000,random5. Lower fence: 1.9253463745117188 Upper fence: 2.5095138549804688.
# For size, case: 75000,random5. Lower fence: 2.2160720825195312 Upper fence: 3.1810989379882812.
# For size, case: 100000,random5. Lower fence: 2.6115570068359375 Upper fence: 3.6813812255859375.
# For size, case: 200000,random5. Lower fence: 3.3833465576171875 Upper fence: 4.4462127685546875.
# For size, case: 300000,random5. Lower fence: 3.9273834228515625 Upper fence: 4.5916900634765625.
# For size, case: 400000,random5. Lower fence: 4.1452484130859375 Upper fence: 5.2623138427734375.
# For size, case: 500000,random5. Lower fence: 4.364501953125 Upper fence: 5.3704833984375.
# For size, case: 600000,random5. Lower fence: 4.2258453369140625 Upper fence: 6.6980133056640625.
# For size, case: 700000,random5. Lower fence: 5.2325439453125 Upper fence: 6.44091796875.
# For size, case: 800000,random5. Lower fence: 5.998680114746094 Upper fence: 7.071128845214844.
# For size, case: 900000,random5. Lower fence: 6.510215759277344 Upper fence: 7.290428161621094.
# For size, case: 1000000,random5. Lower fence: 6.828651428222656 Upper fence: 7.600685119628906.
# For size, case: 25000,random6. Lower fence: 1.4570159912109375 Upper fence: 2.0245208740234375.
# For size, case: 50000,random6. Lower fence: 1.6091766357421875 Upper fence: 2.6863250732421875.
# For size, case: 75000,random6. Lower fence: 2.0642318725585938 Upper fence: 3.2232284545898438.
# For size, case: 100000,random6. Lower fence: 2.6223907470703125 Upper fence: 3.5445098876953125.
# For size, case: 200000,random6. Lower fence: 3.3005523681640625 Upper fence: 4.2939605712890625.
# For size, case: 300000,random6. Lower fence: 3.6885223388671875 Upper fence: 4.4503631591796875.
# For size, case: 400000,random6. Lower fence: 3.37591552734375 Upper fence: 5.96270751953125.
# For size, case: 500000,random6. Lower fence: 4.486747741699219 Upper fence: 5.630485534667969.
# For size, case: 600000,random6. Lower fence: 4.934974670410156 Upper fence: 5.774147033691406.
# For size, case: 700000,random6. Lower fence: 5.477294921875 Upper fence: 6.328125.
# For size, case: 800000,random6. Lower fence: 6.064971923828125 Upper fence: 6.827423095703125.
# For size, case: 900000,random6. Lower fence: 6.528564453125 Upper fence: 7.2374267578125.
# For size, case: 1000000,random6. Lower fence: 6.6523590087890625 Upper fence: 7.5293121337890625.
# For size, case: 25000,random7. Lower fence: 1.4154891967773438 Upper fence: 2.0804672241210938.
# For size, case: 50000,random7. Lower fence: 1.6723556518554688 Upper fence: 2.6410446166992188.
# For size, case: 75000,random7. Lower fence: 2.0024032592773438 Upper fence: 3.2209701538085938.
# For size, case: 100000,random7. Lower fence: 2.6476516723632812 Upper fence: 3.7099685668945312.
# For size, case: 200000,random7. Lower fence: 3.2723846435546875 Upper fence: 4.0465545654296875.
# For size, case: 300000,random7. Lower fence: 3.978485107421875 Upper fence: 4.711761474609375.
# For size, case: 400000,random7. Lower fence: 3.624908447265625 Upper fence: 5.655426025390625.
# For size, case: 500000,random7. Lower fence: 4.483406066894531 Upper fence: 5.179267883300781.
# For size, case: 600000,random7. Lower fence: 4.865242004394531 Upper fence: 5.513862609863281.
# For size, case: 700000,random7. Lower fence: 5.5504150390625 Upper fence: 6.3140869140625.
# For size, case: 800000,random7. Lower fence: 5.902885437011719 Upper fence: 6.647209167480469.
# For size, case: 900000,random7. Lower fence: 6.363136291503906 Upper fence: 6.896766662597656.
# For size, case: 1000000,random7. Lower fence: 6.573539733886719 Upper fence: 7.876091003417969.
# For size, case: 25000,random8. Lower fence: 1.6140670776367188 Upper fence: 2.0839767456054688.
# For size, case: 50000,random8. Lower fence: 1.59918212890625 Upper fence: 2.71185302734375.
# For size, case: 75000,random8. Lower fence: 2.5843048095703125 Upper fence: 3.1084747314453125.
# For size, case: 100000,random8. Lower fence: 2.4138870239257812 Upper fence: 3.5748367309570312.
# For size, case: 200000,random8. Lower fence: 3.394721984863282 Upper fence: 4.33789825439453.
# For size, case: 300000,random8. Lower fence: 3.4417190551757812 Upper fence: 5.018318176269531.
# For size, case: 400000,random8. Lower fence: 4.042335510253906 Upper fence: 5.340736389160156.
# For size, case: 500000,random8. Lower fence: 4.4747467041015625 Upper fence: 5.0173492431640625.
# For size, case: 600000,random8. Lower fence: 4.932044982910156 Upper fence: 5.488136291503906.
# For size, case: 700000,random8. Lower fence: 5.3987579345703125 Upper fence: 6.1792755126953125.
# For size, case: 800000,random8. Lower fence: 5.746917724609375 Upper fence: 6.794403076171875.
# For size, case: 900000,random8. Lower fence: 6.430999755859375 Upper fence: 7.350433349609375.
# For size, case: 1000000,random8. Lower fence: 6.668754577636719 Upper fence: 7.561393737792969.
# For size, case: 25000,random9. Lower fence: 1.4667739868164062 Upper fence: 2.0160293579101562.
# For size, case: 50000,random9. Lower fence: 1.89410400390625 Upper fence: 2.63604736328125.
# For size, case: 75000,random9. Lower fence: 2.459564208984375 Upper fence: 3.167205810546875.
# For size, case: 100000,random9. Lower fence: 2.7644271850585938 Upper fence: 3.6900253295898438.
# For size, case: 200000,random9. Lower fence: 3.4684448242187518 Upper fence: 4.272277832031248.
# For size, case: 300000,random9. Lower fence: 3.7433547973632812 Upper fence: 4.769294738769531.
# For size, case: 400000,random9. Lower fence: 4.142219543457031 Upper fence: 5.173164367675781.
# For size, case: 500000,random9. Lower fence: 4.4983062744140625 Upper fence: 5.1058502197265625.
# For size, case: 600000,random9. Lower fence: 4.9030609130859375 Upper fence: 5.5599212646484375.
# For size, case: 700000,random9. Lower fence: 4.68505859375 Upper fence: 7.3304443359375.
# For size, case: 800000,random9. Lower fence: 6.010833740234375 Upper fence: 6.698333740234375.
# For size, case: 900000,random9. Lower fence: 6.491783142089844 Upper fence: 7.299095153808594.
# For size, case: 1000000,random9. Lower fence: 6.142784118652344 Upper fence: 8.600120544433594.
# For size, case: 25000,random10. Lower fence: 1.40576171875 Upper fence: 2.1458740234375.
# For size, case: 50000,random10. Lower fence: 1.929595947265625 Upper fence: 2.632232666015625.
# For size, case: 75000,random10. Lower fence: 2.30194091796875 Upper fence: 3.35528564453125.
# For size, case: 100000,random10. Lower fence: 2.4627685546875 Upper fence: 3.703857421875.
# For size, case: 200000,random10. Lower fence: 3.2802886962890625 Upper fence: 4.5128326416015625.
# For size, case: 300000,random10. Lower fence: 3.0961380004882812 Upper fence: 5.525276184082031.
# For size, case: 400000,random10. Lower fence: 3.6788482666015625 Upper fence: 5.4947662353515625.
# For size, case: 500000,random10. Lower fence: 4.511322021484375 Upper fence: 5.602874755859375.
# For size, case: 600000,random10. Lower fence: 4.8701324462890625 Upper fence: 5.8835601806640625.
# For size, case: 700000,random10. Lower fence: 5.380706787109375 Upper fence: 6.050750732421875.
# For size, case: 800000,random10. Lower fence: 5.1649932861328125 Upper fence: 7.7923126220703125.
# For size, case: 900000,random10. Lower fence: 6.405433654785156 Upper fence: 7.458351135253906.
# For size, case: 1000000,random10. Lower fence: 6.78057861328125 Upper fence: 7.28350830078125.
# For size, case: 25000,best. Lower fence: 1.2120819091796875 Upper fence: 1.7417449951171875.
# For size, case: 50000,best. Lower fence: 1.614715576171875 Upper fence: 2.311981201171875.
# For size, case: 75000,best. Lower fence: 1.8613128662109375 Upper fence: 2.9598236083984375.
# For size, case: 100000,best. Lower fence: 2.0600357055664062 Upper fence: 3.5572891235351562.
# For size, case: 200000,best. Lower fence: 3.3880157470703134 Upper fence: 4.310623168945312.
# For size, case: 300000,best. Lower fence: 3.9546432495117188 Upper fence: 4.489738464355469.
# For size, case: 400000,best. Lower fence: 4.3472442626953125 Upper fence: 4.8363800048828125.
# For size, case: 500000,best. Lower fence: 4.078178405761719 Upper fence: 5.387809753417969.
# For size, case: 600000,best. Lower fence: 4.942466735839844 Upper fence: 5.406394958496094.
# For size, case: 700000,best. Lower fence: 5.234642028808594 Upper fence: 5.786460876464844.
# For size, case: 800000,best. Lower fence: 5.7613983154296875 Upper fence: 6.1884002685546875.
# For size, case: 900000,best. Lower fence: 6.11083984375 Upper fence: 6.65869140625.
# For size, case: 1000000,best. Lower fence: 5.977455139160156 Upper fence: 7.234474182128906.
# For size, case: 25000,worst. Lower fence: 4.828376770019531 Upper fence: 5.553169250488281.
# For size, case: 50000,worst. Lower fence: 10.156898498535156 Upper fence: 14.331398010253906.
# For size, case: 75000,worst. Lower fence: 23.617752075195305 Upper fence: 24.72773742675782.
# For size, case: 100000,worst. Lower fence: 35.386329650878906 Upper fence: 48.906532287597656.
# For size, case: 200000,worst. Lower fence: 72.56962585449219 Upper fence: 224.5890350341797.
# For size, case: 300000,worst. Lower fence: 304.49635314941406 Upper fence: 402.00941467285156.
# For size, case: 400000,worst. Lower fence: 590.0260772705078 Upper fence: 605.1862335205078.
# For size, case: 500000,worst. Lower fence: 906.247024536133 Upper fence: 973.5919952392576.
# For size, case: 600000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 700000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 800000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 900000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 1000000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 25000,random1. Lower fence: 1.7230377197265625 Upper fence: 2.2260894775390625.
# For size, case: 50000,random1. Lower fence: 1.8521728515625 Upper fence: 2.8887939453125.
# For size, case: 75000,random1. Lower fence: 2.46832275390625 Upper fence: 3.54034423828125.
# For size, case: 100000,random1. Lower fence: 2.58990478515625 Upper fence: 4.23785400390625.
# For size, case: 200000,random1. Lower fence: 3.2857818603515616 Upper fence: 5.016738891601563.
# For size, case: 300000,random1. Lower fence: 4.216804504394531 Upper fence: 5.041694641113281.
# For size, case: 400000,random1. Lower fence: 4.5712890625 Upper fence: 5.16650390625.
# For size, case: 500000,random1. Lower fence: 4.881355285644531 Upper fence: 5.663642883300781.
# For size, case: 600000,random1. Lower fence: 5.207244873046875 Upper fence: 6.457611083984375.
# For size, case: 700000,random1. Lower fence: 5.848487854003906 Upper fence: 6.565589904785156.
# For size, case: 800000,random1. Lower fence: 5.6816482543945295 Upper fence: 8.324653625488283.
# For size, case: 900000,random1. Lower fence: 6.899269104003906 Upper fence: 7.549476623535156.
# For size, case: 1000000,random1. Lower fence: 7.236473083496094 Upper fence: 8.098960876464844.
# For size, case: 25000,random2. Lower fence: 1.7905426025390625 Upper fence: 2.2442779541015625.
# For size, case: 50000,random2. Lower fence: 1.9691848754882812 Upper fence: 2.8233718872070312.
# For size, case: 75000,random2. Lower fence: 2.2015762329101562 Upper fence: 3.8387222290039062.
# For size, case: 100000,random2. Lower fence: 2.770538330078125 Upper fence: 4.051422119140625.
# For size, case: 200000,random2. Lower fence: 3.8241043090820312 Upper fence: 4.538154602050781.
# For size, case: 300000,random2. Lower fence: 3.4631881713867188 Upper fence: 5.837516784667969.
# For size, case: 400000,random2. Lower fence: 4.661491394042969 Upper fence: 5.471488952636719.
# For size, case: 500000,random2. Lower fence: 4.69232177734375 Upper fence: 6.02508544921875.
# For size, case: 600000,random2. Lower fence: 5.365478515625 Upper fence: 5.9461669921875.
# For size, case: 700000,random2. Lower fence: 5.869041442871094 Upper fence: 7.231040954589844.
# For size, case: 800000,random2. Lower fence: 6.350372314453123 Upper fence: 7.962677001953127.
# For size, case: 900000,random2. Lower fence: 6.702705383300781 Upper fence: 8.000617980957031.
# For size, case: 1000000,random2. Lower fence: 7.098182678222656 Upper fence: 8.286476135253906.
# For size, case: 25000,random3. Lower fence: 1.6218719482421875 Upper fence: 2.2054901123046875.
# For size, case: 50000,random3. Lower fence: 1.9872360229492188 Upper fence: 2.7914962768554688.
# For size, case: 75000,random3. Lower fence: 2.4246978759765625 Upper fence: 3.7516021728515625.
# For size, case: 100000,random3. Lower fence: 2.3218154907226562 Upper fence: 4.111427307128906.
# For size, case: 200000,random3. Lower fence: 3.478340148925782 Upper fence: 4.56897735595703.
# For size, case: 300000,random3. Lower fence: 4.161834716796875 Upper fence: 5.274383544921875.
# For size, case: 400000,random3. Lower fence: 3.7828521728515625 Upper fence: 6.4810943603515625.
# For size, case: 500000,random3. Lower fence: 4.8745269775390625 Upper fence: 5.9160308837890625.
# For size, case: 600000,random3. Lower fence: 5.518547058105469 Upper fence: 6.028251647949219.
# For size, case: 700000,random3. Lower fence: 5.429931640625 Upper fence: 7.94287109375.
# For size, case: 800000,random3. Lower fence: 6.513755798339844 Upper fence: 7.421775817871094.
# For size, case: 900000,random3. Lower fence: 6.924873352050783 Upper fence: 7.9100418090820295.
# For size, case: 1000000,random3. Lower fence: 6.7435302734375 Upper fence: 9.0626220703125.
# For size, case: 25000,random4. Lower fence: 1.58013916015625 Upper fence: 2.29815673828125.
# For size, case: 50000,random4. Lower fence: 2.1048736572265625 Upper fence: 2.9904937744140625.
# For size, case: 75000,random4. Lower fence: 2.1280746459960938 Upper fence: 3.6869735717773438.
# For size, case: 100000,random4. Lower fence: 2.6108245849609375 Upper fence: 4.1789398193359375.
# For size, case: 200000,random4. Lower fence: 3.76995849609375 Upper fence: 4.68988037109375.
# For size, case: 300000,random4. Lower fence: 4.0779571533203125 Upper fence: 5.3546905517578125.
# For size, case: 400000,random4. Lower fence: 4.4146270751953125 Upper fence: 5.5093536376953125.
# For size, case: 500000,random4. Lower fence: 5.0218505859375 Upper fence: 5.8250732421875.
# For size, case: 600000,random4. Lower fence: 5.2905731201171875 Upper fence: 6.4327850341796875.
# For size, case: 700000,random4. Lower fence: 6.056449890136719 Upper fence: 6.781364440917969.
# For size, case: 800000,random4. Lower fence: 6.4468994140625 Upper fence: 7.501953125.
# For size, case: 900000,random4. Lower fence: 6.693634033203125 Upper fence: 8.501129150390625.
# For size, case: 1000000,random4. Lower fence: 7.377403259277342 Upper fence: 7.9664535522460955.
# For size, case: 25000,random5. Lower fence: 1.8873214721679688 Upper fence: 2.2769088745117188.
# For size, case: 50000,random5. Lower fence: 1.8824615478515625 Upper fence: 2.9095611572265625.
# For size, case: 75000,random5. Lower fence: 2.6303329467773438 Upper fence: 3.4494857788085938.
# For size, case: 100000,random5. Lower fence: 2.6032791137695312 Upper fence: 4.079414367675781.
# For size, case: 200000,random5. Lower fence: 3.680206298828125 Upper fence: 4.981475830078125.
# For size, case: 300000,random5. Lower fence: 4.1849822998046875 Upper fence: 4.9915008544921875.
# For size, case: 400000,random5. Lower fence: 4.491203308105469 Upper fence: 5.823539733886719.
# For size, case: 500000,random5. Lower fence: 4.8894500732421875 Upper fence: 5.6766815185546875.
# For size, case: 600000,random5. Lower fence: 4.85369873046875 Upper fence: 6.90130615234375.
# For size, case: 700000,random5. Lower fence: 5.8191070556640625 Upper fence: 6.7022857666015625.
# For size, case: 800000,random5. Lower fence: 6.498664855957031 Upper fence: 7.603950500488281.
# For size, case: 900000,random5. Lower fence: 6.8320465087890625 Upper fence: 8.165908813476562.
# For size, case: 1000000,random5. Lower fence: 7.450721740722656 Upper fence: 8.048683166503906.
# For size, case: 25000,random6. Lower fence: 1.6176223754882812 Upper fence: 2.2854080200195312.
# For size, case: 50000,random6. Lower fence: 2.0319595336914062 Upper fence: 2.8183975219726562.
# For size, case: 75000,random6. Lower fence: 2.1870193481445312 Upper fence: 3.5819778442382812.
# For size, case: 100000,random6. Lower fence: 2.7398300170898438 Upper fence: 4.015647888183594.
# For size, case: 200000,random6. Lower fence: 4.057136535644531 Upper fence: 4.441474914550781.
# For size, case: 300000,random6. Lower fence: 4.131874084472656 Upper fence: 4.781593322753906.
# For size, case: 400000,random6. Lower fence: 4.427314758300781 Upper fence: 5.394172668457031.
# For size, case: 500000,random6. Lower fence: 4.838775634765625 Upper fence: 6.068634033203125.
# For size, case: 600000,random6. Lower fence: 5.4380035400390625 Upper fence: 6.1464996337890625.
# For size, case: 700000,random6. Lower fence: 5.896614074707031 Upper fence: 7.003486633300781.
# For size, case: 800000,random6. Lower fence: 6.6149139404296875 Upper fence: 7.2259979248046875.
# For size, case: 900000,random6. Lower fence: 6.7117691040039045 Upper fence: 8.213172912597658.
# For size, case: 1000000,random6. Lower fence: 7.003791809082031 Upper fence: 8.395332336425781.
# For size, case: 25000,random7. Lower fence: 1.6054153442382812 Upper fence: 2.3176345825195312.
# For size, case: 50000,random7. Lower fence: 1.8045578002929688 Upper fence: 2.9843063354492188.
# For size, case: 75000,random7. Lower fence: 2.1842727661132812 Upper fence: 3.6964187622070312.
# For size, case: 100000,random7. Lower fence: 2.5728225708007812 Upper fence: 4.306770324707031.
# For size, case: 200000,random7. Lower fence: 3.6052169799804688 Upper fence: 4.561088562011719.
# For size, case: 300000,random7. Lower fence: 4.3311614990234375 Upper fence: 5.0978851318359375.
# For size, case: 400000,random7. Lower fence: 4.590965270996094 Upper fence: 5.211997985839844.
# For size, case: 500000,random7. Lower fence: 4.9464874267578125 Upper fence: 5.6077423095703125.
# For size, case: 600000,random7. Lower fence: 5.2624664306640625 Upper fence: 6.0250396728515625.
# For size, case: 700000,random7. Lower fence: 5.92547607421875 Upper fence: 7.11456298828125.
# For size, case: 800000,random7. Lower fence: 5.6131134033203125 Upper fence: 8.491897583007812.
# For size, case: 900000,random7. Lower fence: 6.745933532714844 Upper fence: 7.640037536621094.
# For size, case: 1000000,random7. Lower fence: 7.399978637695311 Upper fence: 7.984207153320314.
# For size, case: 25000,random8. Lower fence: 1.84698486328125 Upper fence: 2.30206298828125.
# For size, case: 50000,random8. Lower fence: 1.8661117553710938 Upper fence: 2.9569931030273438.
# For size, case: 75000,random8. Lower fence: 2.4716339111328125 Upper fence: 3.6043243408203125.
# For size, case: 100000,random8. Lower fence: 2.3185272216796875 Upper fence: 4.1280975341796875.
# For size, case: 200000,random8. Lower fence: 3.7280960083007812 Upper fence: 4.670417785644531.
# For size, case: 300000,random8. Lower fence: 4.177787780761719 Upper fence: 4.800895690917969.
# For size, case: 400000,random8. Lower fence: 4.400390625 Upper fence: 5.822998046875.
# For size, case: 500000,random8. Lower fence: 4.844505310058594 Upper fence: 5.555137634277344.
# For size, case: 600000,random8. Lower fence: 5.3341064453125 Upper fence: 5.9776611328125.
# For size, case: 700000,random8. Lower fence: 5.976318359375 Upper fence: 6.5140380859375.
# For size, case: 800000,random8. Lower fence: 6.271293640136719 Upper fence: 7.214225769042969.
# For size, case: 900000,random8. Lower fence: 6.867851257324219 Upper fence: 8.109123229980469.
# For size, case: 1000000,random8. Lower fence: 7.304496765136719 Upper fence: 7.984367370605469.
# For size, case: 25000,random9. Lower fence: 1.6358566284179688 Upper fence: 2.2584762573242188.
# For size, case: 50000,random9. Lower fence: 2.1617050170898438 Upper fence: 2.9355697631835938.
# For size, case: 75000,random9. Lower fence: 2.380767822265625 Upper fence: 3.776885986328125.
# For size, case: 100000,random9. Lower fence: 2.7428436279296875 Upper fence: 4.0649871826171875.
# For size, case: 200000,random9. Lower fence: 3.8567886352539062 Upper fence: 4.570106506347656.
# For size, case: 300000,random9. Lower fence: 4.066436767578125 Upper fence: 5.375518798828125.
# For size, case: 400000,random9. Lower fence: 4.3250274658203125 Upper fence: 5.9551544189453125.
# For size, case: 500000,random9. Lower fence: 4.353607177734375 Upper fence: 6.521575927734375.
# For size, case: 600000,random9. Lower fence: 5.264122009277344 Upper fence: 5.995384216308594.
# For size, case: 700000,random9. Lower fence: 5.217247009277344 Upper fence: 7.811668395996094.
# For size, case: 800000,random9. Lower fence: 6.011428833007814 Upper fence: 8.10188293457031.
# For size, case: 900000,random9. Lower fence: 6.910659790039061 Upper fence: 8.046646118164064.
# For size, case: 1000000,random9. Lower fence: 6.702842712402344 Upper fence: 9.129173278808594.
# For size, case: 25000,random10. Lower fence: 1.6283721923828125 Upper fence: 2.3310089111328125.
# For size, case: 50000,random10. Lower fence: 2.0864486694335938 Upper fence: 3.0035018920898438.
# For size, case: 75000,random10. Lower fence: 2.3272933959960938 Upper fence: 3.8055038452148438.
# For size, case: 100000,random10. Lower fence: 2.5110549926757812 Upper fence: 4.257453918457031.
# For size, case: 200000,random10. Lower fence: 3.8142776489257812 Upper fence: 4.812141418457031.
# For size, case: 300000,random10. Lower fence: 3.7588119506835938 Upper fence: 5.297691345214844.
# For size, case: 400000,random10. Lower fence: 3.936309814453125 Upper fence: 6.270538330078125.
# For size, case: 500000,random10. Lower fence: 5.052459716796875 Upper fence: 5.969818115234375.
# For size, case: 600000,random10. Lower fence: 5.425956726074219 Upper fence: 6.097038269042969.
# For size, case: 700000,random10. Lower fence: 5.8820343017578125 Upper fence: 6.6334991455078125.
# For size, case: 800000,random10. Lower fence: 6.412834167480469 Upper fence: 7.026786804199219.
# For size, case: 900000,random10. Lower fence: 6.910224914550781 Upper fence: 8.131111145019531.
# For size, case: 1000000,random10. Lower fence: 7.183898925781248 Upper fence: 8.066345214843752.
# For size, case: 25000,best. Lower fence: 1.1677627563476562 Upper fence: 1.6889419555664062.
# For size, case: 50000,best. Lower fence: 1.6413803100585938 Upper fence: 2.1986923217773438.
# For size, case: 75000,best. Lower fence: 1.8901901245117188 Upper fence: 2.8094406127929688.
# For size, case: 100000,best. Lower fence: 2.3109130859375 Upper fence: 3.3048095703125.
# For size, case: 200000,best. Lower fence: 3.2556915283203134 Upper fence: 4.257156372070312.
# For size, case: 300000,best. Lower fence: 3.834716796875 Upper fence: 4.4114990234375.
# For size, case: 400000,best. Lower fence: 4.234367370605469 Upper fence: 4.757621765136719.
# For size, case: 500000,best. Lower fence: 4.0223846435546875 Upper fence: 5.2755584716796875.
# For size, case: 600000,best. Lower fence: 4.803688049316406 Upper fence: 5.366859436035156.
# For size, case: 700000,best. Lower fence: 5.195625305175781 Upper fence: 5.715095520019531.
# For size, case: 800000,best. Lower fence: 5.650566101074219 Upper fence: 6.150505065917969.
# For size, case: 900000,best. Lower fence: 6.0647735595703125 Upper fence: 6.5846710205078125.
# For size, case: 1000000,best. Lower fence: 5.964141845703125 Upper fence: 7.101348876953125.
# For size, case: 25000,worst. Lower fence: 4.783348083496094 Upper fence: 5.621177673339844.
# For size, case: 50000,worst. Lower fence: 10.303169250488281 Upper fence: 14.545051574707031.
# For size, case: 75000,worst. Lower fence: 24.02178955078125 Upper fence: 25.69976806640625.
# For size, case: 100000,worst. Lower fence: 36.23280334472655 Upper fence: 50.71278381347658.
# For size, case: 200000,worst. Lower fence: 76.86890411376953 Upper fence: 229.91437530517578.
# For size, case: 300000,worst. Lower fence: 321.8978729248046 Upper fence: 412.6902313232423.
# For size, case: 400000,worst. Lower fence: 609.3886108398438 Upper fence: 630.3967895507812.
# For size, case: 500000,worst. Lower fence: 940.245666503906 Upper fence: 1010.2688598632815.
# For size, case: 600000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 700000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 800000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 900000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 1000000,worst. Lower fence: nan Upper fence: nan.
# For size, case: 25000,random1. Lower fence: 1.58868408203125 Upper fence: 2.15069580078125.
# For size, case: 50000,random1. Lower fence: 1.9019393920898438 Upper fence: 2.6610336303710938.
# For size, case: 75000,random1. Lower fence: 2.5778579711914062 Upper fence: 3.2583389282226562.
# For size, case: 100000,random1. Lower fence: 2.6258544921875 Upper fence: 3.88427734375.
# For size, case: 200000,random1. Lower fence: 3.4734420776367196 Upper fence: 4.291252136230468.
# For size, case: 300000,random1. Lower fence: 4.0135040283203125 Upper fence: 4.9838409423828125.
# For size, case: 400000,random1. Lower fence: 4.5496978759765625 Upper fence: 4.9250640869140625.
# For size, case: 500000,random1. Lower fence: 4.83404541015625 Upper fence: 5.45050048828125.
# For size, case: 600000,random1. Lower fence: 5.069404602050781 Upper fence: 6.336189270019531.
# For size, case: 700000,random1. Lower fence: 5.740455627441406 Upper fence: 6.491981506347656.
# For size, case: 800000,random1. Lower fence: 5.547882080078125 Upper fence: 8.243438720703125.
# For size, case: 900000,random1. Lower fence: 6.814186096191406 Upper fence: 7.402870178222656.
# For size, case: 1000000,random1. Lower fence: 7.1531219482421875 Upper fence: 7.8296356201171875.
# For size, case: 25000,random2. Lower fence: 1.6803817749023438 Upper fence: 2.1510238647460938.
# For size, case: 50000,random2. Lower fence: 1.800689697265625 Upper fence: 2.753692626953125.
# For size, case: 75000,random2. Lower fence: 2.756866455078125 Upper fence: 3.216461181640625.
# For size, case: 100000,random2. Lower fence: 2.5205612182617188 Upper fence: 4.149040222167969.
# For size, case: 200000,random2. Lower fence: 3.7088851928710938 Upper fence: 4.452110290527344.
# For size, case: 300000,random2. Lower fence: 3.322662353515625 Upper fence: 5.664581298828125.
# For size, case: 400000,random2. Lower fence: 4.5593109130859375 Upper fence: 5.3378753662109375.
# For size, case: 500000,random2. Lower fence: 4.792350769042969 Upper fence: 5.429740905761719.
# For size, case: 600000,random2. Lower fence: 5.326835632324219 Upper fence: 5.804313659667969.
# For size, case: 700000,random2. Lower fence: 5.903816223144531 Upper fence: 6.798042297363281.
# For size, case: 800000,random2. Lower fence: 6.532188415527344 Upper fence: 7.380638122558594.
# For size, case: 900000,random2. Lower fence: 6.656097412109375 Upper fence: 7.821380615234375.
# For size, case: 1000000,random2. Lower fence: 6.8695068359375 Upper fence: 8.3551025390625.
# For size, case: 25000,random3. Lower fence: 1.5022659301757812 Upper fence: 2.1235427856445312.
# For size, case: 50000,random3. Lower fence: 1.8380203247070312 Upper fence: 2.7050247192382812.
# For size, case: 75000,random3. Lower fence: 2.5408859252929688 Upper fence: 3.4187545776367188.
# For size, case: 100000,random3. Lower fence: 2.184783935546875 Upper fence: 4.186004638671875.
# For size, case: 200000,random3. Lower fence: 3.402099609375001 Upper fence: 4.427612304687499.
# For size, case: 300000,random3. Lower fence: 4.0274658203125 Upper fence: 5.1483154296875.
# For size, case: 400000,random3. Lower fence: 4.363288879394531 Upper fence: 5.012275695800781.
# For size, case: 500000,random3. Lower fence: 4.644477844238281 Upper fence: 6.123054504394531.
# For size, case: 600000,random3. Lower fence: 5.278739929199219 Upper fence: 6.184074401855469.
# For size, case: 700000,random3. Lower fence: 5.857017517089844 Upper fence: 7.007835388183594.
# For size, case: 800000,random3. Lower fence: 6.211761474609375 Upper fence: 7.692840576171875.
# For size, case: 900000,random3. Lower fence: 6.783584594726561 Upper fence: 7.885635375976564.
# For size, case: 1000000,random3. Lower fence: 6.628440856933594 Upper fence: 9.027793884277344.
# For size, case: 25000,random4. Lower fence: 1.5047760009765625 Upper fence: 2.1716461181640625.
# For size, case: 50000,random4. Lower fence: 2.0231552124023438 Upper fence: 2.8481674194335938.
# For size, case: 75000,random4. Lower fence: 2.012115478515625 Upper fence: 3.560821533203125.
# For size, case: 100000,random4. Lower fence: 2.5577239990234375 Upper fence: 4.0744476318359375.
# For size, case: 200000,random4. Lower fence: 3.6808013916015625 Upper fence: 4.4620513916015625.
# For size, case: 300000,random4. Lower fence: 3.9080123901367188 Upper fence: 5.246452331542969.
# For size, case: 400000,random4. Lower fence: 4.186866760253906 Upper fence: 5.449256896972656.
# For size, case: 500000,random4. Lower fence: 5.014427185058594 Upper fence: 5.636314392089844.
# For size, case: 600000,random4. Lower fence: 5.228309631347656 Upper fence: 6.181739807128906.
# For size, case: 700000,random4. Lower fence: 5.841522216796875 Upper fence: 6.878387451171875.
# For size, case: 800000,random4. Lower fence: 6.31982421875 Upper fence: 7.40673828125.
# For size, case: 900000,random4. Lower fence: 6.986366271972658 Upper fence: 7.8033218383789045.
# For size, case: 1000000,random4. Lower fence: 6.987297058105469 Upper fence: 8.216239929199219.
# For size, case: 25000,random5. Lower fence: 1.6811904907226562 Upper fence: 2.2253189086914062.
# For size, case: 50000,random5. Lower fence: 1.9930572509765625 Upper fence: 2.7109527587890625.
# For size, case: 75000,random5. Lower fence: 2.1347427368164062 Upper fence: 3.3915176391601562.
# For size, case: 100000,random5. Lower fence: 2.8690948486328125 Upper fence: 3.8523712158203125.
# For size, case: 200000,random5. Lower fence: 3.465934753417968 Upper fence: 4.87639617919922.
# For size, case: 300000,random5. Lower fence: 4.089363098144531 Upper fence: 4.867134094238281.
# For size, case: 400000,random5. Lower fence: 4.502372741699219 Upper fence: 5.480583190917969.
# For size, case: 500000,random5. Lower fence: 4.857032775878906 Upper fence: 5.522010803222656.
# For size, case: 600000,random5. Lower fence: 4.404716491699219 Upper fence: 7.241935729980469.
# For size, case: 700000,random5. Lower fence: 5.3748931884765625 Upper fence: 7.2585601806640625.
# For size, case: 800000,random5. Lower fence: 6.4862518310546875 Upper fence: 7.3121795654296875.
# For size, case: 900000,random5. Lower fence: 6.830268859863281 Upper fence: 7.796272277832031.
# For size, case: 1000000,random5. Lower fence: 7.265998840332031 Upper fence: 8.026557922363281.
# For size, case: 25000,random6. Lower fence: 1.60406494140625 Upper fence: 2.04058837890625.
# For size, case: 50000,random6. Lower fence: 1.7995147705078125 Upper fence: 2.7609405517578125.
# For size, case: 75000,random6. Lower fence: 2.5935592651367188 Upper fence: 3.1871261596679688.
# For size, case: 100000,random6. Lower fence: 2.581756591796875 Upper fence: 3.887908935546875.
# For size, case: 200000,random6. Lower fence: 3.6300125122070312 Upper fence: 4.483100891113281.
# For size, case: 300000,random6. Lower fence: 3.9267425537109375 Upper fence: 4.6039886474609375.
# For size, case: 400000,random6. Lower fence: 3.8386459350585938 Upper fence: 6.255210876464844.
# For size, case: 500000,random6. Lower fence: 4.90362548828125 Upper fence: 5.89056396484375.
# For size, case: 600000,random6. Lower fence: 5.238853454589844 Upper fence: 6.123435974121094.
# For size, case: 700000,random6. Lower fence: 5.893165588378906 Upper fence: 6.709266662597656.
# For size, case: 800000,random6. Lower fence: 6.464469909667969 Upper fence: 7.210258483886719.
# For size, case: 900000,random6. Lower fence: 6.856208801269533 Upper fence: 7.6780471801757795.
# For size, case: 1000000,random6. Lower fence: 6.6180191040039045 Upper fence: 8.721229553222658.
# For size, case: 25000,random7. Lower fence: 1.5488433837890625 Upper fence: 2.1491851806640625.
# For size, case: 50000,random7. Lower fence: 1.8517913818359375 Upper fence: 2.7231292724609375.
# For size, case: 75000,random7. Lower fence: 2.3724288940429688 Upper fence: 3.3210983276367188.
# For size, case: 100000,random7. Lower fence: 2.5736236572265625 Upper fence: 3.9702301025390625.
# For size, case: 200000,random7. Lower fence: 3.5133285522460946 Upper fence: 4.338340759277343.
# For size, case: 300000,random7. Lower fence: 4.077995300292969 Upper fence: 5.114311218261719.
# For size, case: 400000,random7. Lower fence: 4.0610504150390625 Upper fence: 5.7485504150390625.
# For size, case: 500000,random7. Lower fence: 4.756874084472656 Upper fence: 5.429054260253906.
# For size, case: 600000,random7. Lower fence: 5.1960906982421875 Upper fence: 5.8887176513671875.
# For size, case: 700000,random7. Lower fence: 5.7672119140625 Upper fence: 6.8966064453125.
# For size, case: 800000,random7. Lower fence: 6.2933349609375 Upper fence: 7.1090087890625.
# For size, case: 900000,random7. Lower fence: 6.6760101318359375 Upper fence: 7.4636077880859375.
# For size, case: 1000000,random7. Lower fence: 6.565406799316406 Upper fence: 8.996009826660156.
# For size, case: 25000,random8. Lower fence: 1.6748275756835938 Upper fence: 2.2223739624023438.
# For size, case: 50000,random8. Lower fence: 1.8556671142578125 Upper fence: 2.7517852783203125.
# For size, case: 75000,random8. Lower fence: 2.3274078369140625 Upper fence: 3.5974273681640625.
# For size, case: 100000,random8. Lower fence: 2.3667068481445312 Upper fence: 3.8749465942382812.
# For size, case: 200000,random8. Lower fence: 3.586853027343751 Upper fence: 4.673400878906249.
# For size, case: 300000,random8. Lower fence: 3.4524002075195312 Upper fence: 5.640449523925781.
# For size, case: 400000,random8. Lower fence: 4.5366668701171875 Upper fence: 5.2405242919921875.
# For size, case: 500000,random8. Lower fence: 4.794700622558594 Upper fence: 5.383018493652344.
# For size, case: 600000,random8. Lower fence: 4.4356231689453125 Upper fence: 7.1903839111328125.
# For size, case: 700000,random8. Lower fence: 5.835052490234375 Upper fence: 6.428192138671875.
# For size, case: 800000,random8. Lower fence: 5.611228942871094 Upper fence: 8.073936462402344.
# For size, case: 900000,random8. Lower fence: 6.9360198974609375 Upper fence: 7.6319427490234375.
# For size, case: 1000000,random8. Lower fence: 7.214767456054689 Upper fence: 7.859054565429686.
# For size, case: 25000,random9. Lower fence: 1.4739456176757812 Upper fence: 2.2264480590820312.
# For size, case: 50000,random9. Lower fence: 2.083343505859375 Upper fence: 2.813201904296875.
# For size, case: 75000,random9. Lower fence: 2.6575775146484375 Upper fence: 3.3243255615234375.
# For size, case: 100000,random9. Lower fence: 2.7053756713867188 Upper fence: 3.9705734252929688.
# For size, case: 200000,random9. Lower fence: 3.5698089599609375 Upper fence: 4.5756683349609375.
# For size, case: 300000,random9. Lower fence: 3.9925689697265625 Upper fence: 5.0883941650390625.
# For size, case: 400000,random9. Lower fence: 4.4801483154296875 Upper fence: 5.3728485107421875.
# For size, case: 500000,random9. Lower fence: 4.801536560058594 Upper fence: 5.457603454589844.
# For size, case: 600000,random9. Lower fence: 5.024993896484375 Upper fence: 6.128265380859375.
# For size, case: 700000,random9. Lower fence: 5.7656097412109375 Upper fence: 6.5319671630859375.
# For size, case: 800000,random9. Lower fence: 6.2862091064453125 Upper fence: 7.1396026611328125.
# For size, case: 900000,random9. Lower fence: 6.7120819091796875 Upper fence: 7.9031219482421875.
# For size, case: 1000000,random9. Lower fence: 6.70172119140625 Upper fence: 8.88812255859375.
# For size, case: 25000,random10. Lower fence: 1.5461502075195312 Upper fence: 2.1994094848632812.
# For size, case: 50000,random10. Lower fence: 2.1029891967773438 Upper fence: 2.8327865600585938.
# For size, case: 75000,random10. Lower fence: 2.4292068481445312 Upper fence: 3.5163040161132812.
# For size, case: 100000,random10. Lower fence: 2.3237838745117188 Upper fence: 4.154167175292969.
# For size, case: 200000,random10. Lower fence: 3.5666732788085946 Upper fence: 4.628623962402343.
# For size, case: 300000,random10. Lower fence: 3.194580078125 Upper fence: 5.7847900390625.
# For size, case: 400000,random10. Lower fence: 4.2528533935546875 Upper fence: 5.1908416748046875.
# For size, case: 500000,random10. Lower fence: 4.903190612792969 Upper fence: 5.759819030761719.
# For size, case: 600000,random10. Lower fence: 5.2312774658203125 Upper fence: 6.3504180908203125.
# For size, case: 700000,random10. Lower fence: 5.781547546386719 Upper fence: 6.489982604980469.
# For size, case: 800000,random10. Lower fence: 5.588661193847656 Upper fence: 8.124000549316406.
# For size, case: 900000,random10. Lower fence: 6.9404449462890625 Upper fence: 7.8479156494140625.
# For size, case: 1000000,random10. Lower fence: 7.36614990234375 Upper fence: 7.68426513671875.

# %%
def meanData(df,type,size):
    mean = df[df["Input case"] == type][df["Size"]==size].mean()
    mean["Input case"] = type
    return mean

def mean_of_dataset(df):
    s = [25000,50000,75000,100000,200000,300000,400000,500000,600000,700000,800000,900000,1000000]
    c = ["best", "worst", "random1","random2","random3","random4","random5","random6","random7","random8","random9","random10",]
    df_of_means = pd.DataFrame({
        "Size":[],
        "Input case":[]
    })
    for case in range(len(c)):
        for size in range(len(s)):
            df_of_means.append(meanData(df, c[case], s[size]))   
    return df_of_means


mean16 = mean_of_dataset(quick16)
mean21 = mean_of_dataset(quick21)
mean23 = mean_of_dataset(quick23)
mean6 = mean_of_dataset(quick6)

def list_of_case(df):
    l = []
    for i in range(len(df)):
        if df["Input case"].iloc[i] not in l:
            l.append(df["Input case"].iloc[i])
    return l


def mean_of_dataset_readCSV(df):
    s = [25000,50000,75000,100000,200000,300000,400000,500000,600000,700000,800000,900000,1000000]
    c = list_of_case(df)
    list_of_means = []
    for case in range(len(c)):
        for size in range(len(s)):
            list_of_means.append(meanData(df, c[case], s[size]))   
    return list_of_means

avg16_readCSV = mean_of_dataset_readCSV(readCSV16)
avg21_readCSV = mean_of_dataset_readCSV(readCSV21)
avg23_readCSV = mean_of_dataset_readCSV(readCSV23)
avg6_readCSV = mean_of_dataset_readCSV(readCSV6)
# Out:
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\2109603394.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   mean = df[df["Input case"] == type][df["Size"]==size].mean()
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\2109603394.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean = df[df["Input case"] == type][df["Size"]==size].mean()
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\2109603394.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_of_means.append(meanData(df, c[case], s[size]))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\mathi\OneDrive\Documents\Git\RAPL_measurements\Java\FinalResults\DataAnalysis.ipynb Cell 36 in <cell line: 19>()
#      <a href='vscode-notebook-cell:/c%3A/Users/mathi/OneDrive/Documents/Git/RAPL_measurements/Java/FinalResults/DataAnalysis.ipynb#Y212sZmlsZQ%3D%3D?line=14'>15</a>             df_of_means.append(meanData(df, c[case], s[size]))
#      <a href='vscode-notebook-cell:/c%3A/Users/mathi/OneDrive/Documents/Git/RAPL_measurements/Java/FinalResults/DataAnalysis.ipynb#Y212sZmlsZQ%3D%3D?line=15'>16</a>     return df_of_means
# ---> <a href='vscode-notebook-cell:/c%3A/Users/mathi/OneDrive/Documents/Git/RAPL_measurements/Java/FinalResults/DataAnalysis.ipynb#Y212sZmlsZQ%3D%3D?line=18'>19</a> mean16 = mean_of_dataset(quick16)
#      <a href='vscode-notebook-cell:/c%3A/Users/mathi/OneDrive/Documents/Git/RAPL_measurements/Java/FinalResults/DataAnalysis.ipynb#Y212sZmlsZQ%3D%3D?line=19'>20</a> mean21 = mean_of_dataset(quick21)
#      <a href='vscode-notebook-cell:/c%3A/Users/mathi/OneDrive/Documents/Git/RAPL_measurements/Java/FinalResults/DataAnalysis.ipynb#Y212sZmlsZQ%3D%3D?line=20'>21</a> mean23 = mean_of_dataset(quick23)
#
# c:\Users\mathi\OneDrive\Documents\Git\RAPL_measurements\Java\FinalResults\DataAnalysis.ipynb Cell 36 in mean_of_dataset(df)
#      <a href='vscode-notebook-cell:/c%3A/Users/mathi/OneDrive/Documents/Git/RAPL_measurements/Java/FinalResults/DataAnalysis.ipynb#Y212sZmlsZQ%3D%3D?line=12'>13</a> for case in range(len(c)):
#      <a href='vscode-notebook-cell:/c%3A/Users/mathi/OneDrive/Documents/Git/RAPL_measurements/Java/FinalResults/DataAnalysis.ipynb#Y212sZmlsZQ%3D%3D?line=13'>14</a>     for size in range(len(s)):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/mathi/OneDrive/Documents/Git/RAPL_measurements/Java/FinalResults/DataAnalysis.ipynb#Y212sZmlsZQ%3D%3D?line=14'>15</a>         df_of_means.append(meanData(df, c[case], s[size]))
#      <a href='vscode-notebook-cell:/c%3A/Users/mathi/OneDrive/Documents/Git/RAPL_measurements/Java/FinalResults/DataAnalysis.ipynb#Y212sZmlsZQ%3D%3D?line=15'>16</a> return df_of_means
#
# File c:\Users\mathi\anaconda3\lib\site-packages\pandas\core\frame.py:9039, in DataFrame.append(self, other, ignore_index, verify_integrity, sort)
#    8936 """
#    8937 Append rows of `other` to the end of caller, returning a new object.
#    8938
#    (...)
#    9029 4  4
#    9030 """
#    9031 warnings.warn(
#    9032     "The frame.append method is deprecated "
#    9033     "and will be removed from pandas in a future version. "
#    (...)
#    9036     stacklevel=find_stack_level(),
#    9037 )
# -> 9039 return self._append(other, ignore_index, verify_integrity, sort)
#
# File c:\Users\mathi\anaconda3\lib\site-packages\pandas\core\frame.py:9055, in DataFrame._append(self, other, ignore_index, verify_integrity, sort)
#    9053     other = Series(other)
#    9054 if other.name is None and not ignore_index:
# -> 9055     raise TypeError(
#    9056         "Can only append a Series if ignore_index=True "
#    9057         "or if the Series has a name"
#    9058     )
#    9060 index = Index([other.name], name=self.index.name)
#    9061 idx_diff = other.index.difference(self.columns)
#
# TypeError: Can only append a Series if ignore_index=True or if the Series has a name

# %%
print(avg16_readCSV)
# Out:
# [PKG (J)          2.147885
# CPU (J)           1.87053
# Memory (J)       0.129033
# Temperature          54.0
# Time (ms)      234.479641
# Size              25000.0
# Input case        random1
# dtype: object, PKG (J)          2.499942
# CPU (J)          2.162758
# Memory (J)       0.150826
# Temperature          57.2
# Time (ms)      268.900725
# Size              50000.0
# Input case        random1
# dtype: object, PKG (J)          3.068246
# CPU (J)          2.670992
# Memory (J)       0.180057
# Temperature          61.0
# Time (ms)      311.495875
# Size              75000.0
# Input case        random1
# dtype: object, PKG (J)          3.545004
# CPU (J)          3.090067
# Memory (J)       0.208476
# Temperature        63.525
# Time (ms)      351.659225
# Size             100000.0
# Input case        random1
# dtype: object, PKG (J)          4.166064
# CPU (J)          3.626851
# Memory (J)       0.233299
# Temperature        65.425
# Time (ms)      420.754475
# Size             200000.0
# Input case        random1
# dtype: object, PKG (J)          5.148955
# CPU (J)          4.497948
# Memory (J)       0.286638
# Temperature        68.625
# Time (ms)      502.796825
# Size             300000.0
# Input case        random1
# dtype: object, PKG (J)         5.281725
# CPU (J)         4.606827
# Memory (J)      0.292763
# Temperature        68.65
# Time (ms)      524.75525
# Size            400000.0
# Input case       random1
# dtype: object, PKG (J)        5.562788
# CPU (J)        4.856322
# Memory (J)     0.303166
# Temperature       68.95
# Time (ms)      558.0528
# Size           500000.0
# Input case      random1
# dtype: object, PKG (J)        6.225883
# CPU (J)        5.430188
# Memory (J)     0.340913
# Temperature      69.125
# Time (ms)      630.6568
# Size           600000.0
# Input case      random1
# dtype: object, PKG (J)          6.625644
# CPU (J)          5.778813
# Memory (J)       0.360461
# Temperature         69.55
# Time (ms)      684.675675
# Size             700000.0
# Input case        random1
# dtype: object, PKG (J)         7.068234
# CPU (J)         6.164241
# Memory (J)       0.36329
# Temperature       68.275
# Time (ms)      753.48895
# Size            800000.0
# Input case       random1
# dtype: object, PKG (J)        7.802293
# CPU (J)        6.805817
# Memory (J)     0.409093
# Temperature      67.775
# Time (ms)      825.2486
# Size           900000.0
# Input case      random1
# dtype: object, PKG (J)         7.940694
# CPU (J)           6.9202
# Memory (J)      0.403487
# Temperature        67.75
# Time (ms)       865.7613
# Size           1000000.0
# Input case       random1
# dtype: object, PKG (J)        2.156194
# CPU (J)        1.877435
# Memory (J)      0.12933
# Temperature        55.0
# Time (ms)      234.7674
# Size            25000.0
# Input case      random2
# dtype: object, PKG (J)          2.487576
# CPU (J)          2.152299
# Memory (J)       0.149463
# Temperature         57.35
# Time (ms)      266.122075
# Size              50000.0
# Input case        random2
# dtype: object, PKG (J)        3.143532
# CPU (J)        2.735562
# Memory (J)     0.185149
# Temperature        61.0
# Time (ms)      318.7178
# Size            75000.0
# Input case      random2
# dtype: object, PKG (J)          3.524022
# CPU (J)          3.077039
# Memory (J)       0.204977
# Temperature          65.0
# Time (ms)      343.020225
# Size             100000.0
# Input case        random2
# dtype: object, PKG (J)         4.43923
# CPU (J)        3.877361
# Memory (J)     0.251878
# Temperature      65.475
# Time (ms)      433.8071
# Size           200000.0
# Input case      random2
# dtype: object, PKG (J)        4.626721
# CPU (J)        4.036449
# Memory (J)     0.251811
# Temperature      68.075
# Time (ms)      459.6159
# Size           300000.0
# Input case      random2
# dtype: object, PKG (J)         5.355374
# CPU (J)         4.676471
# Memory (J)      0.294058
# Temperature        68.65
# Time (ms)      529.08385
# Size            400000.0
# Input case       random2
# dtype: object, PKG (J)         5.618434
# CPU (J)          4.90013
# Memory (J)      0.309055
# Temperature       69.275
# Time (ms)      566.15125
# Size            500000.0
# Input case       random2
# dtype: object, PKG (J)          6.001924
# CPU (J)          5.232466
# Memory (J)       0.327679
# Temperature         69.15
# Time (ms)      613.372525
# Size             600000.0
# Input case        random2
# dtype: object, PKG (J)          6.750305
# CPU (J)          5.887119
# Memory (J)       0.367555
# Temperature        70.175
# Time (ms)      693.184175
# Size             700000.0
# Input case        random2
# dtype: object, PKG (J)          7.651224
# CPU (J)          6.681305
# Memory (J)       0.403531
# Temperature          69.0
# Time (ms)      791.891475
# Size             800000.0
# Input case        random2
# dtype: object, PKG (J)        7.571913
# CPU (J)        6.604039
# Memory (J)     0.381293
# Temperature      68.775
# Time (ms)      822.9569
# Size           900000.0
# Input case      random2
# dtype: object, PKG (J)         7.930566
# CPU (J)         6.917834
# Memory (J)      0.401923
# Temperature        68.35
# Time (ms)      860.59805
# Size           1000000.0
# Input case       random2
# dtype: object, PKG (J)        2.065598
# CPU (J)        1.797174
# Memory (J)     0.125377
# Temperature        55.0
# Time (ms)      223.5403
# Size            25000.0
# Input case      random3
# dtype: object, PKG (J)          2.483801
# CPU (J)           2.15826
# Memory (J)       0.147412
# Temperature        58.575
# Time (ms)      255.582025
# Size              50000.0
# Input case        random3
# dtype: object, PKG (J)         3.152509
# CPU (J)         2.744797
# Memory (J)      0.186444
# Temperature       61.875
# Time (ms)      318.79395
# Size             75000.0
# Input case       random3
# dtype: object, PKG (J)         3.292902
# CPU (J)         2.868483
# Memory (J)      0.193164
# Temperature       64.075
# Time (ms)      326.52985
# Size            100000.0
# Input case       random3
# dtype: object, PKG (J)          4.156494
# CPU (J)          3.620848
# Memory (J)       0.231676
# Temperature          66.2
# Time (ms)      420.168325
# Size             200000.0
# Input case        random3
# dtype: object, PKG (J)         5.206673
# CPU (J)         4.550348
# Memory (J)      0.289871
# Temperature       69.125
# Time (ms)      504.65415
# Size            300000.0
# Input case       random3
# dtype: object, PKG (J)          5.069225
# CPU (J)          4.416115
# Memory (J)       0.273897
# Temperature          69.1
# Time (ms)      517.252125
# Size             400000.0
# Input case        random3
# dtype: object, PKG (J)          5.774809
# CPU (J)          5.043814
# Memory (J)       0.319905
# Temperature        70.025
# Time (ms)      570.728025
# Size             500000.0
# Input case        random3
# dtype: object, PKG (J)         6.180733
# CPU (J)         5.398862
# Memory (J)      0.334958
# Temperature       70.775
# Time (ms)      621.44815
# Size            600000.0
# Input case       random3
# dtype: object, PKG (J)          6.925468
# CPU (J)          6.041676
# Memory (J)        0.38007
# Temperature          69.4
# Time (ms)      705.128175
# Size             700000.0
# Input case        random3
# dtype: object, PKG (J)          7.324974
# CPU (J)          6.391167
# Memory (J)       0.383734
# Temperature         68.85
# Time (ms)      764.973725
# Size             800000.0
# Input case        random3
# dtype: object, PKG (J)        7.655775
# CPU (J)        6.681244
# Memory (J)     0.392375
# Temperature        69.4
# Time (ms)       815.375
# Size           900000.0
# Input case      random3
# dtype: object, PKG (J)         7.930084
# CPU (J)         6.916782
# Memory (J)      0.403139
# Temperature       67.725
# Time (ms)      860.70645
# Size           1000000.0
# Input case       random3
# dtype: object, PKG (J)          2.052583
# CPU (J)          1.781075
# Memory (J)       0.124614
# Temperature          55.0
# Time (ms)      230.624925
# Size              25000.0
# Input case        random4
# dtype: object, PKG (J)          2.614388
# CPU (J)          2.268579
# Memory (J)       0.154251
# Temperature        58.175
# Time (ms)      273.458225
# Size              50000.0
# Input case        random4
# dtype: object, PKG (J)        3.035547
# CPU (J)        2.638461
# Memory (J)     0.182587
# Temperature        61.5
# Time (ms)      307.2464
# Size            75000.0
# Input case      random4
# dtype: object, PKG (J)        3.509315
# CPU (J)        3.061147
# Memory (J)     0.204305
# Temperature      64.925
# Time (ms)      343.2547
# Size           100000.0
# Input case      random4
# dtype: object, PKG (J)         4.587126
# CPU (J)         4.005956
# Memory (J)      0.262038
# Temperature       66.225
# Time (ms)      444.90395
# Size            200000.0
# Input case       random4
# dtype: object, PKG (J)         4.923659
# CPU (J)         4.297098
# Memory (J)      0.274644
# Temperature       68.025
# Time (ms)      485.46725
# Size            300000.0
# Input case       random4
# dtype: object, PKG (J)        5.045192
# CPU (J)        4.397487
# Memory (J)     0.273637
# Temperature      68.225
# Time (ms)      514.2255
# Size           400000.0
# Input case      random4
# dtype: object, PKG (J)        5.810422
# CPU (J)        5.066277
# Memory (J)     0.320378
# Temperature      69.325
# Time (ms)      582.2106
# Size           500000.0
# Input case      random4
# dtype: object, PKG (J)        6.285043
# CPU (J)        5.487599
# Memory (J)     0.344836
# Temperature       70.55
# Time (ms)         630.2
# Size           600000.0
# Input case      random4
# dtype: object, PKG (J)         6.83273
# CPU (J)        5.960841
# Memory (J)     0.374988
# Temperature      69.325
# Time (ms)      700.6762
# Size           700000.0
# Input case      random4
# dtype: object, PKG (J)        7.358647
# CPU (J)        6.423715
# Memory (J)     0.387277
# Temperature       69.95
# Time (ms)      764.2641
# Size           800000.0
# Input case      random4
# dtype: object, PKG (J)        8.035086
# CPU (J)        7.016245
# Memory (J)     0.421498
# Temperature      68.625
# Time (ms)      841.8852
# Size           900000.0
# Input case      random4
# dtype: object, PKG (J)          7.948647
# CPU (J)          6.931767
# Memory (J)       0.400726
# Temperature        68.475
# Time (ms)      872.546325
# Size            1000000.0
# Input case        random4
# dtype: object, PKG (J)         2.186635
# CPU (J)         1.899715
# Memory (J)      0.131058
# Temperature         55.0
# Time (ms)      241.10555
# Size             25000.0
# Input case       random5
# dtype: object, PKG (J)         2.531288
# CPU (J)         2.193349
# Memory (J)      0.152704
# Temperature         59.0
# Time (ms)      267.74885
# Size             50000.0
# Input case       random5
# dtype: object, PKG (J)          2.991911
# CPU (J)          2.598557
# Memory (J)       0.178825
# Temperature         62.35
# Time (ms)      306.552725
# Size              75000.0
# Input case        random5
# dtype: object, PKG (J)          3.465033
# CPU (J)           3.01955
# Memory (J)       0.200787
# Temperature          65.0
# Time (ms)      342.612025
# Size             100000.0
# Input case        random5
# dtype: object, PKG (J)         4.640889
# CPU (J)         4.063925
# Memory (J)      0.260777
# Temperature       66.975
# Time (ms)      440.39805
# Size            200000.0
# Input case       random5
# dtype: object, PKG (J)        4.942961
# CPU (J)        4.313002
# Memory (J)     0.276822
# Temperature        68.2
# Time (ms)      485.9141
# Size           300000.0
# Input case      random5
# dtype: object, PKG (J)          5.368887
# CPU (J)            4.6858
# Memory (J)       0.296521
# Temperature         67.75
# Time (ms)      533.128625
# Size             400000.0
# Input case        random5
# dtype: object, PKG (J)          5.475343
# CPU (J)          4.771262
# Memory (J)       0.295572
# Temperature        69.025
# Time (ms)      560.761925
# Size             500000.0
# Input case        random5
# dtype: object, PKG (J)          5.903152
# CPU (J)          5.147906
# Memory (J)        0.31469
# Temperature          69.9
# Time (ms)      612.170325
# Size             600000.0
# Input case        random5
# dtype: object, PKG (J)         6.434566
# CPU (J)          5.60706
# Memory (J)      0.346735
# Temperature       69.875
# Time (ms)      673.88765
# Size            700000.0
# Input case       random5
# dtype: object, PKG (J)          7.499193
# CPU (J)          6.544952
# Memory (J)       0.389679
# Temperature        69.225
# Time (ms)      785.915325
# Size             800000.0
# Input case        random5
# dtype: object, PKG (J)        7.712085
# CPU (J)        6.728967
# Memory (J)     0.397922
# Temperature      68.825
# Time (ms)      817.9941
# Size           900000.0
# Input case      random5
# dtype: object, PKG (J)         8.188812
# CPU (J)         7.149254
# Memory (J)      0.421277
# Temperature       68.075
# Time (ms)      873.73055
# Size           1000000.0
# Input case       random5
# dtype: object, PKG (J)        2.057677
# CPU (J)         1.77791
# Memory (J)     0.123242
# Temperature        55.0
# Time (ms)      225.9685
# Size            25000.0
# Input case      random6
# dtype: object, PKG (J)        2.508087
# CPU (J)        2.176126
# Memory (J)     0.148053
# Temperature      59.725
# Time (ms)      262.6875
# Size            50000.0
# Input case      random6
# dtype: object, PKG (J)          3.001375
# CPU (J)          2.606119
# Memory (J)       0.178148
# Temperature         62.65
# Time (ms)      310.303525
# Size              75000.0
# Input case        random6
# dtype: object, PKG (J)          3.449649
# CPU (J)          3.006076
# Memory (J)       0.202258
# Temperature          64.8
# Time (ms)      341.991225
# Size             100000.0
# Input case        random6
# dtype: object, PKG (J)            4.4838
# CPU (J)          3.913545
# Memory (J)       0.253381
# Temperature          67.4
# Time (ms)      438.330475
# Size             200000.0
# Input case        random6
# dtype: object, PKG (J)          4.771887
# CPU (J)          4.158574
# Memory (J)       0.267035
# Temperature         66.85
# Time (ms)      477.590875
# Size             300000.0
# Input case        random6
# dtype: object, PKG (J)        5.077194
# CPU (J)        4.423256
# Memory (J)     0.275171
# Temperature      67.575
# Time (ms)      518.7152
# Size           400000.0
# Input case      random6
# dtype: object, PKG (J)         5.900812
# CPU (J)         5.149661
# Memory (J)      0.321898
# Temperature       69.875
# Time (ms)      587.75645
# Size            500000.0
# Input case       random6
# dtype: object, PKG (J)         6.155321
# CPU (J)         5.367204
# Memory (J)      0.337627
# Temperature       69.375
# Time (ms)      626.35965
# Size            600000.0
# Input case       random6
# dtype: object, PKG (J)        6.769444
# CPU (J)        5.903342
# Memory (J)     0.373489
# Temperature      68.825
# Time (ms)      695.6501
# Size           700000.0
# Input case      random6
# dtype: object, PKG (J)          7.368449
# CPU (J)          6.433209
# Memory (J)       0.388182
# Temperature        67.875
# Time (ms)      764.697425
# Size             800000.0
# Input case        random6
# dtype: object, PKG (J)          7.770842
# CPU (J)          6.778052
# Memory (J)       0.399548
# Temperature         68.25
# Time (ms)      830.292575
# Size             900000.0
# Input case        random6
# dtype: object, PKG (J)          7.953203
# CPU (J)          6.935954
# Memory (J)       0.402055
# Temperature        68.125
# Time (ms)      869.384875
# Size            1000000.0
# Input case        random6
# dtype: object, PKG (J)          2.094113
# CPU (J)          1.805852
# Memory (J)       0.126375
# Temperature          55.0
# Time (ms)      232.466375
# Size              25000.0
# Input case        random7
# dtype: object, PKG (J)          2.508255
# CPU (J)          2.168497
# Memory (J)       0.151863
# Temperature        59.275
# Time (ms)      269.432075
# Size              50000.0
# Input case        random7
# dtype: object, PKG (J)         2.969595
# CPU (J)         2.583842
# Memory (J)      0.173627
# Temperature       62.925
# Time (ms)      300.11065
# Size             75000.0
# Input case       random7
# dtype: object, PKG (J)          3.609654
# CPU (J)          3.151277
# Memory (J)        0.20972
# Temperature        65.925
# Time (ms)      352.388175
# Size             100000.0
# Input case        random7
# dtype: object, PKG (J)        4.165384
# CPU (J)        3.627203
# Memory (J)     0.232082
# Temperature        66.9
# Time (ms)      418.6177
# Size           200000.0
# Input case      random7
# dtype: object, PKG (J)          5.175551
# CPU (J)          4.524675
# Memory (J)       0.287051
# Temperature        69.325
# Time (ms)      500.027575
# Size             300000.0
# Input case        random7
# dtype: object, PKG (J)          5.085316
# CPU (J)          4.434138
# Memory (J)       0.274214
# Temperature        68.825
# Time (ms)      515.861275
# Size             400000.0
# Input case        random7
# dtype: object, PKG (J)         5.501129
# CPU (J)         4.798645
# Memory (J)      0.297842
# Temperature         69.6
# Time (ms)      555.53965
# Size            500000.0
# Input case       random7
# dtype: object, PKG (J)         5.859338
# CPU (J)         5.101819
# Memory (J)       0.31644
# Temperature       69.425
# Time (ms)      610.89655
# Size            600000.0
# Input case       random7
# dtype: object, PKG (J)        6.732378
# CPU (J)        5.872021
# Memory (J)     0.364671
# Temperature      69.675
# Time (ms)      692.7517
# Size           700000.0
# Input case      random7
# dtype: object, PKG (J)          7.071724
# CPU (J)          6.166089
# Memory (J)       0.364888
# Temperature        69.325
# Time (ms)      755.569675
# Size             800000.0
# Input case        random7
# dtype: object, PKG (J)         7.508955
# CPU (J)         6.543533
# Memory (J)      0.383751
# Temperature       68.075
# Time (ms)      812.28695
# Size            900000.0
# Input case       random7
# dtype: object, PKG (J)         7.965416
# CPU (J)         6.950018
# Memory (J)      0.403931
# Temperature         67.1
# Time (ms)      864.25395
# Size           1000000.0
# Input case       random7
# dtype: object, PKG (J)          2.193169
# CPU (J)          1.900409
# Memory (J)       0.129137
# Temperature        55.125
# Time (ms)      234.200925
# Size              25000.0
# Input case        random8
# dtype: object, PKG (J)          2.510796
# CPU (J)          2.182846
# Memory (J)       0.147487
# Temperature          59.3
# Time (ms)      256.760025
# Size              50000.0
# Input case        random8
# dtype: object, PKG (J)        3.097604
# CPU (J)        2.685939
# Memory (J)     0.184206
# Temperature        62.0
# Time (ms)      324.6887
# Size            75000.0
# Input case      random8
# dtype: object, PKG (J)          3.301283
# CPU (J)          2.872807
# Memory (J)       0.191792
# Temperature          65.0
# Time (ms)      331.890025
# Size             100000.0
# Input case        random8
# dtype: object, PKG (J)          4.581325
# CPU (J)          3.992654
# Memory (J)       0.260742
# Temperature        67.175
# Time (ms)      455.249225
# Size             200000.0
# Input case        random8
# dtype: object, PKG (J)        4.602296
# CPU (J)        4.014095
# Memory (J)     0.251317
# Temperature        69.4
# Time (ms)      458.2091
# Size           300000.0
# Input case      random8
# dtype: object, PKG (J)          5.482834
# CPU (J)          4.785265
# Memory (J)       0.306787
# Temperature          69.4
# Time (ms)      539.115175
# Size             400000.0
# Input case        random8
# dtype: object, PKG (J)           5.65927
# CPU (J)          4.933185
# Memory (J)       0.312613
# Temperature        69.425
# Time (ms)      569.874425
# Size             500000.0
# Input case        random8
# dtype: object, PKG (J)        5.944737
# CPU (J)        5.183698
# Memory (J)     0.317986
# Temperature      69.525
# Time (ms)      615.4526
# Size           600000.0
# Input case      random8
# dtype: object, PKG (J)          6.593303
# CPU (J)          5.746291
# Memory (J)       0.356242
# Temperature         68.85
# Time (ms)      684.978175
# Size             700000.0
# Input case        random8
# dtype: object, PKG (J)         7.030084
# CPU (J)         6.130023
# Memory (J)      0.363692
# Temperature       69.225
# Time (ms)      748.51005
# Size            800000.0
# Input case       random8
# dtype: object, PKG (J)          7.963257
# CPU (J)          6.943321
# Memory (J)       0.416472
# Temperature        67.925
# Time (ms)      845.997275
# Size             900000.0
# Input case        random8
# dtype: object, PKG (J)          7.899722
# CPU (J)          6.882487
# Memory (J)       0.405324
# Temperature          68.0
# Time (ms)      859.611375
# Size            1000000.0
# Input case        random8
# dtype: object, PKG (J)          2.063519
# CPU (J)          1.778487
# Memory (J)       0.123747
# Temperature          56.0
# Time (ms)      228.885125
# Size              25000.0
# Input case        random9
# dtype: object, PKG (J)        2.658479
# CPU (J)        2.305263
# Memory (J)     0.157079
# Temperature        60.0
# Time (ms)      280.7675
# Size            50000.0
# Input case      random9
# dtype: object, PKG (J)         3.135298
# CPU (J)         2.729663
# Memory (J)      0.183986
# Temperature         62.7
# Time (ms)      316.29855
# Size             75000.0
# Input case       random9
# dtype: object, PKG (J)          3.522307
# CPU (J)          3.069437
# Memory (J)       0.205247
# Temperature        64.575
# Time (ms)      349.386875
# Size             100000.0
# Input case        random9
# dtype: object, PKG (J)          4.513443
# CPU (J)          3.936806
# Memory (J)       0.256465
# Temperature         67.15
# Time (ms)      441.540075
# Size             200000.0
# Input case        random9
# dtype: object, PKG (J)          4.999966
# CPU (J)           4.36768
# Memory (J)       0.280319
# Temperature         68.95
# Time (ms)      483.228275
# Size             300000.0
# Input case        random9
# dtype: object, PKG (J)        5.469804
# CPU (J)        4.770108
# Memory (J)     0.306487
# Temperature      69.575
# Time (ms)      540.7174
# Size           400000.0
# Input case      random9
# dtype: object, PKG (J)         5.461948
# CPU (J)         4.763803
# Memory (J)      0.293843
# Temperature       68.975
# Time (ms)      558.19815
# Size            500000.0
# Input case       random9
# dtype: object, PKG (J)           5.90377
# CPU (J)          5.148663
# Memory (J)       0.316704
# Temperature         69.15
# Time (ms)      608.982325
# Size             600000.0
# Input case        random9
# dtype: object, PKG (J)          6.541747
# CPU (J)          5.709637
# Memory (J)       0.346959
# Temperature         68.45
# Time (ms)      685.942425
# Size             700000.0
# Input case        random9
# dtype: object, PKG (J)          7.200436
# CPU (J)          6.281023
# Memory (J)       0.376904
# Temperature        68.575
# Time (ms)      754.528625
# Size             800000.0
# Input case        random9
# dtype: object, PKG (J)           7.82888
# CPU (J)          6.828601
# Memory (J)       0.408739
# Temperature        68.975
# Time (ms)      830.556775
# Size             900000.0
# Input case        random9
# dtype: object, PKG (J)          8.260994
# CPU (J)          7.206755
# Memory (J)        0.43517
# Temperature        68.525
# Time (ms)      884.988325
# Size            1000000.0
# Input case        random9
# dtype: object, PKG (J)           2.08512
# CPU (J)          1.801302
# Memory (J)       0.124078
# Temperature        56.175
# Time (ms)      227.501325
# Size              25000.0
# Input case       random10
# dtype: object, PKG (J)         2.641801
# CPU (J)         2.295033
# Memory (J)      0.155733
# Temperature         60.3
# Time (ms)      272.90555
# Size             50000.0
# Input case      random10
# dtype: object, PKG (J)         3.107678
# CPU (J)         2.704704
# Memory (J)      0.181654
# Temperature        63.15
# Time (ms)      314.20285
# Size             75000.0
# Input case      random10
# dtype: object, PKG (J)         3.560045
# CPU (J)         3.102184
# Memory (J)      0.205876
# Temperature        65.85
# Time (ms)      352.13475
# Size            100000.0
# Input case      random10
# dtype: object, PKG (J)           4.52422
# CPU (J)          3.958331
# Memory (J)       0.250946
# Temperature        67.575
# Time (ms)      431.017575
# Size             200000.0
# Input case       random10
# dtype: object, PKG (J)        4.677319
# CPU (J)        4.080841
# Memory (J)     0.254556
# Temperature        69.7
# Time (ms)      462.2926
# Size           300000.0
# Input case     random10
# dtype: object, PKG (J)          5.071045
# CPU (J)          4.423904
# Memory (J)       0.272929
# Temperature        69.075
# Time (ms)      510.766775
# Size             400000.0
# Input case       random10
# dtype: object, PKG (J)         6.004968
# CPU (J)         5.244092
# Memory (J)      0.331059
# Temperature       70.875
# Time (ms)      596.00295
# Size            500000.0
# Input case      random10
# dtype: object, PKG (J)          6.184706
# CPU (J)          5.397598
# Memory (J)       0.337383
# Temperature         69.75
# Time (ms)      625.273475
# Size             600000.0
# Input case       random10
# dtype: object, PKG (J)          6.498787
# CPU (J)          5.666348
# Memory (J)       0.351649
# Temperature         69.65
# Time (ms)      676.822925
# Size             700000.0
# Input case       random10
# dtype: object, PKG (J)          7.006216
# CPU (J)          6.109084
# Memory (J)       0.361661
# Temperature          69.5
# Time (ms)      746.385625
# Size             800000.0
# Input case       random10
# dtype: object, PKG (J)        7.706548
# CPU (J)        6.724385
# Memory (J)     0.398048
# Temperature      69.775
# Time (ms)      816.4252
# Size           900000.0
# Input case     random10
# dtype: object, PKG (J)         8.063553
# CPU (J)         7.031384
# Memory (J)      0.417603
# Temperature       68.675
# Time (ms)      870.21425
# Size           1000000.0
# Input case      random10
# dtype: object, PKG (J)               2.118719
# CPU (J)               1.822107
# Memory (J)            0.124878
# Temperature             66.825
# Time (ms)           233.607325
# Size                   25000.0
# Input case     countingrandom1
# dtype: object, PKG (J)               2.556203
# CPU (J)               2.212219
# Memory (J)            0.149033
# Temperature             66.475
# Time (ms)           266.028025
# Size                   50000.0
# Input case     countingrandom1
# dtype: object, PKG (J)                3.07495
# CPU (J)               2.673428
# Memory (J)            0.180656
# Temperature             68.525
# Time (ms)            303.79125
# Size                   75000.0
# Input case     countingrandom1
# dtype: object, PKG (J)               3.319315
# CPU (J)                2.88855
# Memory (J)            0.191345
# Temperature             69.975
# Time (ms)            324.91285
# Size                  100000.0
# Input case     countingrandom1
# dtype: object, PKG (J)               4.424405
# CPU (J)               3.852773
# Memory (J)             0.24472
# Temperature               72.0
# Time (ms)           426.046825
# Size                  200000.0
# Input case     countingrandom1
# dtype: object, PKG (J)               4.773956
# CPU (J)               4.148386
# Memory (J)            0.263173
# Temperature             71.275
# Time (ms)           468.007175
# Size                  300000.0
# Input case     countingrandom1
# dtype: object, PKG (J)               5.234161
# CPU (J)               4.552144
# Memory (J)            0.285101
# Temperature               72.5
# Time (ms)            514.74325
# Size                  400000.0
# Input case     countingrandom1
# dtype: object, PKG (J)                5.49783
# CPU (J)               4.786156
# Memory (J)            0.294286
# Temperature             72.175
# Time (ms)             553.8784
# Size                  500000.0
# Input case     countingrandom1
# dtype: object, PKG (J)               5.989059
# CPU (J)               5.220705
# Memory (J)            0.327518
# Temperature               71.8
# Time (ms)            601.93955
# Size                  600000.0
# Input case     countingrandom1
# dtype: object, PKG (J)                6.38329
# CPU (J)               5.538409
# Memory (J)            0.342245
# Temperature             71.675
# Time (ms)             647.8589
# Size                  700000.0
# Input case     countingrandom1
# dtype: object, PKG (J)               7.047504
# CPU (J)               6.115573
# Memory (J)            0.365588
# Temperature             71.775
# Time (ms)           737.744825
# Size                  800000.0
# Input case     countingrandom1
# dtype: object, PKG (J)               7.444382
# CPU (J)               6.472318
# Memory (J)            0.378896
# Temperature             69.925
# Time (ms)             790.9656
# Size                  900000.0
# Input case     countingrandom1
# dtype: object, PKG (J)               8.007446
# CPU (J)               6.970338
# Memory (J)            0.406816
# Temperature             69.175
# Time (ms)           860.325825
# Size                 1000000.0
# Input case     countingrandom1
# dtype: object, PKG (J)               2.113881
# CPU (J)               1.819926
# Memory (J)             0.12475
# Temperature             66.325
# Time (ms)             227.9995
# Size                   25000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               2.596254
# CPU (J)               2.249132
# Memory (J)            0.151488
# Temperature              67.15
# Time (ms)           266.630975
# Size                   50000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               3.065126
# CPU (J)               2.668114
# Memory (J)            0.178372
# Temperature             68.875
# Time (ms)           299.105625
# Size                   75000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               3.363745
# CPU (J)               2.931587
# Memory (J)            0.190414
# Temperature               70.6
# Time (ms)           324.720275
# Size                  100000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               4.399269
# CPU (J)               3.831926
# Memory (J)            0.238843
# Temperature             71.775
# Time (ms)           419.999525
# Size                  200000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               4.828349
# CPU (J)               4.199561
# Memory (J)            0.264906
# Temperature              72.45
# Time (ms)           466.832525
# Size                  300000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               5.166275
# CPU (J)                4.49257
# Memory (J)            0.278815
# Temperature             71.825
# Time (ms)             508.5642
# Size                  400000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               5.593839
# CPU (J)               4.876497
# Memory (J)            0.303067
# Temperature              71.55
# Time (ms)           561.794175
# Size                  500000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               6.015508
# CPU (J)               5.240613
# Memory (J)            0.327402
# Temperature             71.225
# Time (ms)           613.119225
# Size                  600000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               6.450237
# CPU (J)               5.598309
# Memory (J)            0.342683
# Temperature              71.45
# Time (ms)             663.6098
# Size                  700000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               6.972214
# CPU (J)               6.047534
# Memory (J)            0.366202
# Temperature             71.125
# Time (ms)            725.61875
# Size                  800000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               7.578635
# CPU (J)               6.596773
# Memory (J)            0.391199
# Temperature             70.625
# Time (ms)              797.856
# Size                  900000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               7.959448
# CPU (J)               6.931175
# Memory (J)            0.409937
# Temperature               70.4
# Time (ms)             841.9839
# Size                 1000000.0
# Input case     countingrandom2
# dtype: object, PKG (J)               2.083423
# CPU (J)               1.789555
# Memory (J)            0.123477
# Temperature             65.675
# Time (ms)             230.9153
# Size                   25000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               2.538275
# CPU (J)               2.198203
# Memory (J)            0.148866
# Temperature             67.675
# Time (ms)           259.631725
# Size                   50000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               3.136826
# CPU (J)               2.727097
# Memory (J)            0.181401
# Temperature               69.1
# Time (ms)           310.317225
# Size                   75000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               3.553188
# CPU (J)               3.096956
# Memory (J)             0.20204
# Temperature             70.675
# Time (ms)           342.718175
# Size                  100000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               4.288026
# CPU (J)               3.727602
# Memory (J)            0.235635
# Temperature              72.45
# Time (ms)           415.404875
# Size                  200000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               4.667999
# CPU (J)               4.060965
# Memory (J)            0.252049
# Temperature               72.3
# Time (ms)             454.7335
# Size                  300000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               5.256522
# CPU (J)               4.572182
# Memory (J)            0.286218
# Temperature             71.175
# Time (ms)            513.45755
# Size                  400000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               5.631873
# CPU (J)               4.906552
# Memory (J)            0.309232
# Temperature             71.975
# Time (ms)           560.605825
# Size                  500000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               5.897066
# CPU (J)               5.140373
# Memory (J)            0.318568
# Temperature             71.475
# Time (ms)            597.09425
# Size                  600000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               6.390714
# CPU (J)               5.548885
# Memory (J)             0.34082
# Temperature             70.975
# Time (ms)             648.4888
# Size                  700000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               7.019032
# CPU (J)               6.086671
# Memory (J)            0.365372
# Temperature               70.5
# Time (ms)           739.519075
# Size                  800000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               7.632967
# CPU (J)               6.648186
# Memory (J)            0.390175
# Temperature             70.825
# Time (ms)            801.51545
# Size                  900000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               7.937152
# CPU (J)               6.910875
# Memory (J)                 0.4
# Temperature             69.775
# Time (ms)           856.242475
# Size                 1000000.0
# Input case     countingrandom3
# dtype: object, PKG (J)               2.106923
# CPU (J)                1.81433
# Memory (J)            0.123993
# Temperature               66.0
# Time (ms)             227.5024
# Size                   25000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               2.568636
# CPU (J)               2.227946
# Memory (J)            0.150009
# Temperature             67.775
# Time (ms)           259.114375
# Size                   50000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               3.133923
# CPU (J)               2.730534
# Memory (J)            0.180511
# Temperature               70.2
# Time (ms)           303.680825
# Size                   75000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               3.450235
# CPU (J)               3.005948
# Memory (J)            0.197287
# Temperature             70.775
# Time (ms)             333.0508
# Size                  100000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               4.311595
# CPU (J)               3.751562
# Memory (J)            0.236333
# Temperature             72.125
# Time (ms)           414.672275
# Size                  200000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               4.683179
# CPU (J)                4.06628
# Memory (J)            0.255328
# Temperature             71.875
# Time (ms)           462.866175
# Size                  300000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               5.205556
# CPU (J)               4.524619
# Memory (J)            0.281444
# Temperature             71.575
# Time (ms)             515.7956
# Size                  400000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               5.503085
# CPU (J)               4.786475
# Memory (J)            0.298296
# Temperature             71.025
# Time (ms)             563.8026
# Size                  500000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               5.983612
# CPU (J)               5.218004
# Memory (J)            0.322871
# Temperature               71.1
# Time (ms)             608.8066
# Size                  600000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               6.295117
# CPU (J)                5.46165
# Memory (J)            0.332301
# Temperature             71.675
# Time (ms)             646.2899
# Size                  700000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               6.925705
# CPU (J)               6.007898
# Memory (J)            0.357451
# Temperature             70.275
# Time (ms)             730.2557
# Size                  800000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               7.521315
# CPU (J)               6.540828
# Memory (J)            0.385448
# Temperature             69.625
# Time (ms)             806.2668
# Size                  900000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               7.833575
# CPU (J)               6.816885
# Memory (J)            0.404306
# Temperature             69.525
# Time (ms)           831.151525
# Size                 1000000.0
# Input case     countingrandom4
# dtype: object, PKG (J)               2.025119
# CPU (J)               1.741756
# Memory (J)            0.120732
# Temperature               66.0
# Time (ms)              220.886
# Size                   25000.0
# Input case     countingrandom5
# dtype: object, PKG (J)               2.573882
# CPU (J)               2.230705
# Memory (J)            0.150226
# Temperature              67.95
# Time (ms)           261.779925
# Size                   50000.0
# Input case     countingrandom5
# dtype: object, PKG (J)               3.142056
# CPU (J)               2.736314
# Memory (J)            0.180603
# Temperature             69.675
# Time (ms)            306.01235
# Size                   75000.0
# Input case     countingrandom5
# dtype: object, PKG (J)               3.475417
# CPU (J)               3.024147
# Memory (J)            0.199667
# Temperature             71.025
# Time (ms)           339.017875
# Size                  100000.0
# Input case     countingrandom5
# dtype: object, PKG (J)               4.265532
# CPU (J)               3.703941
# Memory (J)            0.232219
# Temperature             72.825
# Time (ms)            419.45335
# Size                  200000.0
# Input case     countingrandom5
# dtype: object, PKG (J)               4.741223
# CPU (J)               4.127708
# Memory (J)             0.25791
# Temperature             71.125
# Time (ms)            456.67085
# Size                  300000.0
# Input case     countingrandom5
# dtype: object, PKG (J)               5.224294
# CPU (J)               4.544225
# Memory (J)            0.284251
# Temperature              70.85
# Time (ms)           510.785025
# Size                  400000.0
# Input case     countingrandom5
# dtype: object, PKG (J)               5.519925
# CPU (J)               4.813484
# Memory (J)            0.300027
# Temperature             71.425
# Time (ms)           552.128825
# Size                  500000.0
# Input case     countingrandom5
# dtype: object, PKG (J)               6.039148
# CPU (J)               5.266924
# Memory (J)            0.330113
# Temperature             71.575
# Time (ms)            606.45075
# Size                  600000.0
# Input case     countingrandom5
# dtype: object, PKG (J)                6.41657
# CPU (J)               5.567458
# Memory (J)            0.341505
# Temperature              70.55
# Time (ms)            660.51115
# Size                  700000.0
# Input case     countingrandom5
# dtype: object, PKG (J)               6.859712
# CPU (J)               5.953212
# Memory (J)            0.352953
# Temperature             69.775
# Time (ms)            721.34175
# Size                  800000.0
# Input case     countingrandom5
# dtype: object, PKG (J)               7.403273
# CPU (J)               6.439684
# Memory (J)            0.375665
# Temperature              69.05
# Time (ms)           795.328575
# Size                  900000.0
# Input case     countingrandom5
# dtype: object, PKG (J)               7.874561
# CPU (J)               6.853999
# Memory (J)            0.400856
# Temperature               69.7
# Time (ms)           844.796775
# Size                 1000000.0
# Input case     countingrandom5
# dtype: object, PKG (J)               2.013065
# CPU (J)               1.730296
# Memory (J)            0.119714
# Temperature               65.1
# Time (ms)           221.280625
# Size                   25000.0
# Input case     countingrandom6
# dtype: object, PKG (J)                  2.539
# CPU (J)               2.198166
# Memory (J)            0.149379
# Temperature             67.275
# Time (ms)           261.992825
# Size                   50000.0
# Input case     countingrandom6
# dtype: object, PKG (J)               3.062772
# CPU (J)               2.664992
# Memory (J)            0.178584
# Temperature             69.625
# Time (ms)           300.532425
# Size                   75000.0
# Input case     countingrandom6
# dtype: object, PKG (J)               3.339645
# CPU (J)               2.906528
# Memory (J)            0.191534
# Temperature             71.225
# Time (ms)             323.7263
# Size                  100000.0
# Input case     countingrandom6
# dtype: object, PKG (J)               4.304951
# CPU (J)               3.743901
# Memory (J)            0.234932
# Temperature             71.575
# Time (ms)            417.99605
# Size                  200000.0
# Input case     countingrandom6
# dtype: object, PKG (J)               4.717302
# CPU (J)               4.099483
# Memory (J)            0.257718
# Temperature             72.125
# Time (ms)           461.879325
# Size                  300000.0
# Input case     countingrandom6
# dtype: object, PKG (J)               5.155232
# CPU (J)               4.478351
# Memory (J)            0.279527
# Temperature             70.475
# Time (ms)            516.59855
# Size                  400000.0
# Input case     countingrandom6
# dtype: object, PKG (J)               5.464252
# CPU (J)               4.761621
# Memory (J)            0.295477
# Temperature              71.55
# Time (ms)           551.988675
# Size                  500000.0
# Input case     countingrandom6
# dtype: object, PKG (J)               6.168738
# CPU (J)               5.382747
# Memory (J)            0.337384
# Temperature               71.1
# Time (ms)             615.8853
# Size                  600000.0
# Input case     countingrandom6
# dtype: object, PKG (J)               6.331339
# CPU (J)               5.493604
# Memory (J)             0.33662
# Temperature             71.175
# Time (ms)           648.019975
# Size                  700000.0
# Input case     countingrandom6
# dtype: object, PKG (J)               6.898286
# CPU (J)               5.991821
# Memory (J)            0.353766
# Temperature              69.45
# Time (ms)           731.240525
# Size                  800000.0
# Input case     countingrandom6
# dtype: object, PKG (J)               7.635161
# CPU (J)                6.65199
# Memory (J)            0.388435
# Temperature             70.525
# Time (ms)             812.1001
# Size                  900000.0
# Input case     countingrandom6
# dtype: object, PKG (J)               7.981155
# CPU (J)                6.94785
# Memory (J)            0.407462
# Temperature             68.725
# Time (ms)           857.415025
# Size                 1000000.0
# Input case     countingrandom6
# dtype: object, PKG (J)               2.010843
# CPU (J)               1.723419
# Memory (J)            0.120984
# Temperature             65.475
# Time (ms)            227.76155
# Size                   25000.0
# Input case     countingrandom7
# dtype: object, PKG (J)               2.684477
# CPU (J)               2.329433
# Memory (J)            0.154265
# Temperature               67.4
# Time (ms)            271.18095
# Size                   50000.0
# Input case     countingrandom7
# dtype: object, PKG (J)               3.078691
# CPU (J)               2.676593
# Memory (J)            0.177567
# Temperature               69.5
# Time (ms)            303.09785
# Size                   75000.0
# Input case     countingrandom7
# dtype: object, PKG (J)               3.515306
# CPU (J)               3.060637
# Memory (J)            0.199533
# Temperature               71.0
# Time (ms)            340.48525
# Size                  100000.0
# Input case     countingrandom7
# dtype: object, PKG (J)               4.338217
# CPU (J)               3.776169
# Memory (J)            0.236198
# Temperature               72.0
# Time (ms)           418.022625
# Size                  200000.0
# Input case     countingrandom7
# dtype: object, PKG (J)               4.695615
# CPU (J)               4.086728
# Memory (J)            0.254668
# Temperature              72.05
# Time (ms)           453.130125
# Size                  300000.0
# Input case     countingrandom7
# dtype: object, PKG (J)                5.11291
# CPU (J)               4.444426
# Memory (J)            0.277397
# Temperature             70.875
# Time (ms)             511.8805
# Size                  400000.0
# Input case     countingrandom7
# dtype: object, PKG (J)                5.63931
# CPU (J)               4.918651
# Memory (J)            0.308887
# Temperature             71.475
# Time (ms)            559.11625
# Size                  500000.0
# Input case     countingrandom7
# dtype: object, PKG (J)               5.898323
# CPU (J)               5.140413
# Memory (J)            0.319366
# Temperature             70.775
# Time (ms)           596.317575
# Size                  600000.0
# Input case     countingrandom7
# dtype: object, PKG (J)               6.508588
# CPU (J)                5.65567
# Memory (J)            0.348918
# Temperature               71.3
# Time (ms)           653.299575
# Size                  700000.0
# Input case     countingrandom7
# dtype: object, PKG (J)               7.042471
# CPU (J)               6.112462
# Memory (J)            0.373289
# Temperature               71.2
# Time (ms)            725.46015
# Size                  800000.0
# Input case     countingrandom7
# dtype: object, PKG (J)               7.491058
# CPU (J)               6.523631
# Memory (J)            0.385124
# Temperature               70.0
# Time (ms)            789.48795
# Size                  900000.0
# Input case     countingrandom7
# dtype: object, PKG (J)               7.910054
# CPU (J)               6.887822
# Memory (J)            0.407072
# Temperature             69.625
# Time (ms)           839.536375
# Size                 1000000.0
# Input case     countingrandom7
# dtype: object, PKG (J)               1.999092
# CPU (J)                1.71725
# Memory (J)            0.119652
# Temperature               65.2
# Time (ms)            219.76195
# Size                   25000.0
# Input case     countingrandom8
# dtype: object, PKG (J)               2.568713
# CPU (J)               2.221106
# Memory (J)            0.152403
# Temperature               67.0
# Time (ms)           263.789775
# Size                   50000.0
# Input case     countingrandom8
# dtype: object, PKG (J)               3.115312
# CPU (J)               2.706427
# Memory (J)            0.178871
# Temperature               70.0
# Time (ms)             311.6424
# Size                   75000.0
# Input case     countingrandom8
# dtype: object, PKG (J)               3.404955
# CPU (J)               2.960771
# Memory (J)             0.19236
# Temperature               70.4
# Time (ms)           329.665825
# Size                  100000.0
# Input case     countingrandom8
# dtype: object, PKG (J)               4.427943
# CPU (J)               3.849335
# Memory (J)            0.243805
# Temperature             72.125
# Time (ms)             430.2072
# Size                  200000.0
# Input case     countingrandom8
# dtype: object, PKG (J)               4.737221
# CPU (J)               4.120786
# Memory (J)            0.259015
# Temperature             72.925
# Time (ms)           461.345925
# Size                  300000.0
# Input case     countingrandom8
# dtype: object, PKG (J)               5.135602
# CPU (J)               4.466638
# Memory (J)            0.277794
# Temperature               71.9
# Time (ms)             516.4548
# Size                  400000.0
# Input case     countingrandom8
# dtype: object, PKG (J)               5.607751
# CPU (J)               4.890233
# Memory (J)            0.303726
# Temperature              71.25
# Time (ms)            566.18905
# Size                  500000.0
# Input case     countingrandom8
# dtype: object, PKG (J)               5.936751
# CPU (J)                5.17603
# Memory (J)            0.321774
# ...
# Temperature           67.32
# Time (ms)         202.69774
# Size                25000.0
# Input case     countingbest
# dtype: object, PKG (J)            2.293692
# CPU (J)            1.983376
# Memory (J)         0.129911
# Temperature            68.3
# Time (ms)         237.90731
# Size                50000.0
# Input case     countingbest
# dtype: object, PKG (J)            2.692477
# CPU (J)            2.331048
# Memory (J)         0.151719
# Temperature         69.8125
# Time (ms)        267.997445
# Size                75000.0
# Input case     countingbest
# dtype: object, PKG (J)            3.018074
# CPU (J)            2.616806
# Memory (J)         0.168692
# Temperature         71.3225
# Time (ms)        296.066875
# Size               100000.0
# Input case     countingbest
# dtype: object, PKG (J)            4.026674
# CPU (J)            3.496772
# Memory (J)         0.223842
# Temperature         72.2075
# Time (ms)        386.841145
# Size               200000.0
# Input case     countingbest
# dtype: object, PKG (J)            4.363708
# CPU (J)            3.791455
# Memory (J)         0.242412
# Temperature          72.645
# Time (ms)        416.094803
# Size               300000.0
# Input case     countingbest
# dtype: object, PKG (J)            4.711743
# CPU (J)            4.092732
# Memory (J)         0.261938
# Temperature           73.51
# Time (ms)        449.123148
# Size               400000.0
# Input case     countingbest
# dtype: object, PKG (J)            4.991936
# CPU (J)             4.33091
# Memory (J)         0.278538
# Temperature         73.3475
# Time (ms)         481.26346
# Size               500000.0
# Input case     countingbest
# dtype: object, PKG (J)            5.299104
# CPU (J)            4.593495
# Memory (J)         0.296696
# Temperature         73.1575
# Time (ms)        517.022295
# Size               600000.0
# Input case     countingbest
# dtype: object, PKG (J)            5.540518
# CPU (J)            4.800865
# Memory (J)         0.310802
# Temperature          73.075
# Time (ms)         546.00028
# Size               700000.0
# Input case     countingbest
# dtype: object, PKG (J)            5.992076
# CPU (J)             5.18676
# Memory (J)          0.33009
# Temperature         72.1425
# Time (ms)          606.7332
# Size               800000.0
# Input case     countingbest
# dtype: object, PKG (J)            6.401206
# CPU (J)            5.536407
# Memory (J)         0.346064
# Temperature           70.82
# Time (ms)         667.59322
# Size               900000.0
# Input case     countingbest
# dtype: object, PKG (J)            6.716368
# CPU (J)            5.806957
# Memory (J)         0.362949
# Temperature         70.4125
# Time (ms)        707.245305
# Size              1000000.0
# Input case     countingbest
# dtype: object, PKG (J)              2.14204
# CPU (J)             1.839476
# Memory (J)           0.12338
# Temperature          68.7925
# Time (ms)         223.942802
# Size                 25000.0
# Input case     countingworst
# dtype: object, PKG (J)             2.599889
# CPU (J)             2.243048
# Memory (J)          0.151022
# Temperature          69.6425
# Time (ms)         261.153877
# Size                 50000.0
# Input case     countingworst
# dtype: object, PKG (J)              3.10262
# CPU (J)             2.687241
# Memory (J)          0.178875
# Temperature          71.4675
# Time (ms)          300.75066
# Size                 75000.0
# Input case     countingworst
# dtype: object, PKG (J)             3.510044
# CPU (J)             3.046754
# Memory (J)          0.197469
# Temperature            72.76
# Time (ms)         334.208462
# Size                100000.0
# Input case     countingworst
# dtype: object, PKG (J)             4.336103
# CPU (J)             3.765606
# Memory (J)           0.23745
# Temperature           73.045
# Time (ms)         416.091083
# Size                200000.0
# Input case     countingworst
# dtype: object, PKG (J)             4.782413
# CPU (J)             4.152119
# Memory (J)          0.259988
# Temperature          73.6625
# Time (ms)         463.827598
# Size                300000.0
# Input case     countingworst
# dtype: object, PKG (J)              5.36441
# CPU (J)             4.661467
# Memory (J)           0.29071
# Temperature           73.255
# Time (ms)         517.993673
# Size                400000.0
# Input case     countingworst
# dtype: object, PKG (J)             5.650074
# CPU (J)             4.909597
# Memory (J)          0.302653
# Temperature          73.5925
# Time (ms)         559.091312
# Size                500000.0
# Input case     countingworst
# dtype: object, PKG (J)                5.992
# CPU (J)              5.20102
# Memory (J)          0.319352
# Temperature          72.2775
# Time (ms)         606.297218
# Size                600000.0
# Input case     countingworst
# dtype: object, PKG (J)             6.485897
# CPU (J)             5.635772
# Memory (J)          0.346647
# Temperature            72.31
# Time (ms)           652.6034
# Size                700000.0
# Input case     countingworst
# dtype: object, PKG (J)              6.90676
# CPU (J)             5.994706
# Memory (J)           0.35792
# Temperature            71.01
# Time (ms)          718.51703
# Size                800000.0
# Input case     countingworst
# dtype: object, PKG (J)             7.572811
# CPU (J)             6.577484
# Memory (J)          0.382021
# Temperature           70.105
# Time (ms)         804.174508
# Size                900000.0
# Input case     countingworst
# dtype: object, PKG (J)             7.975748
# CPU (J)             6.927859
# Memory (J)          0.410441
# Temperature          70.4075
# Time (ms)         841.184185
# Size               1000000.0
# Input case     countingworst
# dtype: object, PKG (J)          2.050114
# CPU (J)          1.761409
# Memory (J)       0.117301
# Temperature        68.195
# Time (ms)      213.158348
# Size              25000.0
# Input case     mergeworst
# dtype: object, PKG (J)           2.58171
# CPU (J)           2.22667
# Memory (J)       0.148759
# Temperature         69.99
# Time (ms)      260.644248
# Size              50000.0
# Input case     mergeworst
# dtype: object, PKG (J)          2.933916
# CPU (J)          2.538647
# Memory (J)       0.170647
# Temperature       71.1575
# Time (ms)      286.142608
# Size              75000.0
# Input case     mergeworst
# dtype: object, PKG (J)          3.333636
# CPU (J)          2.888468
# Memory (J)       0.191408
# Temperature         71.95
# Time (ms)      321.772107
# Size             100000.0
# Input case     mergeworst
# dtype: object, PKG (J)           4.14109
# CPU (J)          3.593872
# Memory (J)       0.225906
# Temperature         72.49
# Time (ms)       400.19973
# Size             200000.0
# Input case     mergeworst
# dtype: object, PKG (J)          4.565854
# CPU (J)          3.963798
# Memory (J)       0.246611
# Temperature        72.525
# Time (ms)       442.86913
# Size             300000.0
# Input case     mergeworst
# dtype: object, PKG (J)          5.007515
# CPU (J)          4.344383
# Memory (J)       0.269617
# Temperature         72.63
# Time (ms)      495.073505
# Size             400000.0
# Input case     mergeworst
# dtype: object, PKG (J)          5.511694
# CPU (J)          4.782201
# Memory (J)        0.30327
# Temperature       73.6425
# Time (ms)      537.262628
# Size             500000.0
# Input case     mergeworst
# dtype: object, PKG (J)          5.772966
# CPU (J)          5.009047
# Memory (J)       0.307535
# Temperature         72.07
# Time (ms)      586.399355
# Size             600000.0
# Input case     mergeworst
# dtype: object, PKG (J)          6.152551
# CPU (J)          5.333138
# Memory (J)       0.336102
# Temperature       71.6325
# Time (ms)      618.672028
# Size             700000.0
# Input case     mergeworst
# dtype: object, PKG (J)          6.709013
# CPU (J)          5.815922
# Memory (J)       0.347778
# Temperature       70.8425
# Time (ms)       708.01315
# Size             800000.0
# Input case     mergeworst
# dtype: object, PKG (J)          7.167867
# CPU (J)          6.209115
# Memory (J)        0.37527
# Temperature       70.2775
# Time (ms)      757.387742
# Size             900000.0
# Input case     mergeworst
# dtype: object, PKG (J)          7.570176
# CPU (J)          6.570011
# Memory (J)       0.398994
# Temperature       69.6025
# Time (ms)      804.514668
# Size            1000000.0
# Input case     mergeworst
# dtype: object, PKG (J)          1.957623
# CPU (J)          1.683999
# Memory (J)       0.115056
# Temperature       67.8025
# Time (ms)      207.799083
# Size              25000.0
# Input case      quickbest
# dtype: object, PKG (J)          2.450886
# CPU (J)          2.111214
# Memory (J)       0.143077
# Temperature        68.795
# Time (ms)      251.935925
# Size              50000.0
# Input case      quickbest
# dtype: object, PKG (J)          2.953286
# CPU (J)          2.557169
# Memory (J)       0.171897
# Temperature         70.46
# Time (ms)      289.439957
# Size              75000.0
# Input case      quickbest
# dtype: object, PKG (J)          3.306489
# CPU (J)           2.86712
# Memory (J)       0.189283
# Temperature       71.6525
# Time (ms)      317.866357
# Size             100000.0
# Input case      quickbest
# dtype: object, PKG (J)          4.140354
# CPU (J)          3.594029
# Memory (J)       0.225163
# Temperature         72.39
# Time (ms)      402.220055
# Size             200000.0
# Input case      quickbest
# dtype: object, PKG (J)          4.546566
# CPU (J)          3.944747
# Memory (J)       0.246287
# Temperature       72.1825
# Time (ms)      446.255368
# Size             300000.0
# Input case      quickbest
# dtype: object, PKG (J)         4.983309
# CPU (J)         4.325647
# Memory (J)      0.268494
# Temperature      71.9725
# Time (ms)      493.09335
# Size            400000.0
# Input case     quickbest
# dtype: object, PKG (J)         5.357915
# CPU (J)         4.646893
# Memory (J)      0.289417
# Temperature        71.64
# Time (ms)      539.47408
# Size            500000.0
# Input case     quickbest
# dtype: object, PKG (J)          5.740552
# CPU (J)          4.981866
# Memory (J)       0.306475
# Temperature         71.55
# Time (ms)      585.648288
# Size             600000.0
# Input case      quickbest
# dtype: object, PKG (J)          6.133658
# CPU (J)          5.320072
# Memory (J)       0.328113
# Temperature       70.7825
# Time (ms)      632.732432
# Size             700000.0
# Input case      quickbest
# dtype: object, PKG (J)          6.703125
# CPU (J)          5.817243
# Memory (J)       0.346658
# Temperature         71.28
# Time (ms)      708.600182
# Size             800000.0
# Input case      quickbest
# dtype: object, PKG (J)          7.192336
# CPU (J)          6.257258
# Memory (J)       0.365906
# Temperature       68.3975
# Time (ms)      779.212708
# Size             900000.0
# Input case      quickbest
# dtype: object, PKG (J)          7.591264
# CPU (J)          6.606765
# Memory (J)       0.387426
# Temperature        70.035
# Time (ms)      823.002363
# Size            1000000.0
# Input case      quickbest
# dtype: object, PKG (J)             1.950402
# CPU (J)             1.674245
# Memory (J)          0.116738
# Temperature            67.08
# Time (ms)          210.78561
# Size                 25000.0
# Input case     reversesorted
# dtype: object, PKG (J)             2.445003
# CPU (J)             2.109499
# Memory (J)          0.144397
# Temperature          68.4975
# Time (ms)         251.640802
# Size                 50000.0
# Input case     reversesorted
# dtype: object, PKG (J)             2.953915
# CPU (J)             2.559525
# Memory (J)            0.1731
# Temperature          71.3875
# Time (ms)           285.9376
# Size                 75000.0
# Input case     reversesorted
# dtype: object, PKG (J)             3.315426
# CPU (J)             2.872889
# Memory (J)           0.19308
# Temperature           71.805
# Time (ms)          320.01362
# Size                100000.0
# Input case     reversesorted
# dtype: object, PKG (J)             4.239861
# CPU (J)             3.676845
# Memory (J)          0.237477
# Temperature           71.545
# Time (ms)         416.263085
# Size                200000.0
# Input case     reversesorted
# dtype: object, PKG (J)             4.613681
# CPU (J)             4.003572
# Memory (J)          0.255302
# Temperature            72.22
# Time (ms)         451.147977
# Size                300000.0
# Input case     reversesorted
# dtype: object, PKG (J)             5.052874
# CPU (J)             4.379688
# Memory (J)          0.278259
# Temperature          71.3125
# Time (ms)         503.020142
# Size                400000.0
# Input case     reversesorted
# dtype: object, PKG (J)             5.407097
# CPU (J)             4.686636
# Memory (J)          0.295439
# Temperature           71.685
# Time (ms)         545.766832
# Size                500000.0
# Input case     reversesorted
# dtype: object, PKG (J)             5.794444
# CPU (J)             5.027423
# Memory (J)          0.314099
# Temperature            71.18
# Time (ms)         590.261202
# Size                600000.0
# Input case     reversesorted
# dtype: object, PKG (J)             6.163198
# CPU (J)             5.342981
# Memory (J)          0.334066
# Temperature           71.065
# Time (ms)         635.582708
# Size                700000.0
# Input case     reversesorted
# dtype: object, PKG (J)             6.739979
# CPU (J)             5.842816
# Memory (J)          0.356776
# Temperature          69.7575
# Time (ms)         715.787405
# Size                800000.0
# Input case     reversesorted
# dtype: object, PKG (J)              7.21931
# CPU (J)              6.27688
# Memory (J)          0.374866
# Temperature          69.6425
# Time (ms)          781.98718
# Size                900000.0
# Input case     reversesorted
# dtype: object, PKG (J)             7.617709
# CPU (J)             6.624136
# Memory (J)          0.394776
# Temperature          69.0475
# Time (ms)         828.741642
# Size               1000000.0
# Input case     reversesorted
# dtype: object, PKG (J)          1.951284
# CPU (J)          1.675568
# Memory (J)       0.114904
# Temperature         66.81
# Time (ms)      212.509282
# Size              25000.0
# Input case         sorted
# dtype: object, PKG (J)          2.457156
# CPU (J)          2.122784
# Memory (J)       0.142485
# Temperature        68.145
# Time (ms)      250.272843
# Size              50000.0
# Input case         sorted
# dtype: object, PKG (J)         2.936526
# CPU (J)         2.540114
# Memory (J)      0.171393
# Temperature      69.8275
# Time (ms)      290.08978
# Size             75000.0
# Input case        sorted
# dtype: object, PKG (J)         3.297438
# CPU (J)         2.858426
# Memory (J)       0.18944
# Temperature      71.2625
# Time (ms)      318.77132
# Size            100000.0
# Input case        sorted
# dtype: object, PKG (J)          4.168365
# CPU (J)          3.621822
# Memory (J)       0.226708
# Temperature        72.865
# Time (ms)      401.085523
# Size             200000.0
# Input case         sorted
# dtype: object, PKG (J)          4.558671
# CPU (J)          3.955654
# Memory (J)       0.247783
# Temperature        72.335
# Time (ms)      444.284225
# Size             300000.0
# Input case         sorted
# dtype: object, PKG (J)            5.0142
# CPU (J)          4.349488
# Memory (J)       0.271227
# Temperature         71.57
# Time (ms)      496.093395
# Size             400000.0
# Input case         sorted
# dtype: object, PKG (J)          5.363359
# CPU (J)          4.652222
# Memory (J)       0.289645
# Temperature        72.305
# Time (ms)      538.242457
# Size             500000.0
# Input case         sorted
# dtype: object, PKG (J)          5.759692
# CPU (J)          4.999208
# Memory (J)       0.308421
# Temperature        72.005
# Time (ms)      584.606162
# Size             600000.0
# Input case         sorted
# dtype: object, PKG (J)          6.141303
# CPU (J)          5.324648
# Memory (J)       0.330076
# Temperature       70.9225
# Time (ms)      631.174158
# Size             700000.0
# Input case         sorted
# dtype: object, PKG (J)          6.694673
# CPU (J)          5.804621
# Memory (J)       0.348876
# Temperature        70.145
# Time (ms)      706.168678
# Size             800000.0
# Input case         sorted
# dtype: object, PKG (J)           7.18114
# CPU (J)          6.245171
# Memory (J)       0.367191
# Temperature       69.3275
# Time (ms)      776.021028
# Size             900000.0
# Input case         sorted
# dtype: object, PKG (J)          7.577645
# CPU (J)          6.591036
# Memory (J)       0.388028
# Temperature          68.9
# Time (ms)      826.044165
# Size            1000000.0
# Input case         sorted
# dtype: object]

# %%
def makeCPU_sub_readCSV(inList):
    for i in range(len(inList)):
        case = inList[i]["Input case"]
        size = inList[i]["Size"]
        inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]

makeCPU_sub_readCSV(mean16)
makeCPU_sub_readCSV(mean21)
makeCPU_sub_readCSV(mean23)
makeCPU_sub_readCSV(mean6)
# Out:
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# ...
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4120\944867960.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inList[i]["CPU - readCSV"] = inList[i]["CPU (J)"] - readCSV16[readCSV16["Input case"] == case][readCSV16["Size"]==size].mean()["CPU (J)"]

# %%
mean16[1]
# Out:
# PKG (J)            2.161093
# CPU (J)            1.859081
# Memory (J)         0.131125
# Temperature           61.25
# Time (ms)        233.795242
# Size                50000.0
# Input case             best
# CPU - readCSV           NaN
# dtype: object

# %%
plt.figure(figsize=(20,10))
for i in range(len(avg16)):
    plt.plot( avg16[i]["Size"],avg16[i]["CPU - BG"],"o", color = "red")

for i in range(len(avg21)):
    plt.plot( avg21[i]["Size"],avg21[i]["CPU - BG"],"o", color = "green")

for i in range(len(avg23)):
    plt.plot( avg23[i]["Size"],avg23[i]["CPU - BG"],"o", color = "blue")

for i in range(len(avg6)):
    plt.plot( avg6[i]["Size"],avg6[i]["CPU - BG"],"o", color = "orange")
plt.title("readCSV subtracted from quicksort for each PC")
plt.xlabel("Input size")
plt.ylabel("Energy consumed by CPU (J) minus readCSV")
plt.show()

plt.figure(figsize=(20,10))
for i in range(len(avg16)):
    plt.plot( avg16[i]["Size"],avg16[i]["CPU (J)"] ,"o", color = "red")

for i in range(len(avg21)):
    plt.plot( avg21[i]["Size"],avg21[i]["CPU (J)"],"o", color = "green")

for i in range(len(avg23)):
    plt.plot( avg23[i]["Size"],avg23[i]["CPU (J)"],"o", color = "blue")

for i in range(len(avg6)):
    plt.plot( avg6[i]["Size"],avg6[i]["CPU (J)"],"o", color = "orange")
plt.title("raw data from quicksort for each PC")
plt.xlabel("Input size")
plt.ylabel("Energy consumed by CPU (J)")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #### Mergesort

# %% [markdown]
# #### Countingsort

# %% [markdown]
# #### Bubblesort
