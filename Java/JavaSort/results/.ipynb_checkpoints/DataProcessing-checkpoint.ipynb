# %% [markdown]
# The name column in the CSV should have the name of the test algorithm or what ever
# followed by the size of the array tested on.
#
#     Example: "merge-sort10000"
#
# NO spaces in the CSV:
#
#     Example: merge-sort10000,8.603332519531250000,7.480468750000000000,,,892.347
#
#     NOT:     merge-sort10000 ; 8.603332519531250000 , 7.480468750000000000 , , , 892.347
#
# Then simply name your cell:
#
#     print("Merge sort Data 10000 - 100000")
#
# Diffine the sizes of your arrays:
#
#     sizes = [i*10000 for i in range(1,11)]
#
# Calculate mean time for each array:
#
#     s = meanTimePrDataSize(df, "name", sizes)
#
# And plot the graphs:
#
#     showGraphs(df, s)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dfMB = pd.read_csv("JavaSort.csv")
dfRandomTests = pd.read_csv("randomJavaSortKristina.csv")
dfBestCaseSorted = pd.read_csv("bestJavaSort.csv")

# %%
def meanTimePrDataSize(df, name, sizes):
    df.columns = ["Name","PKG","CPU", "GPU" , "DRAM?" , "Time (sec)"]
    d = {}
    for i in range(len(sizes)):
        d[str(sizes[i])] = df[df["Name"] == (name+str(sizes[i]))] ["Time (sec)"].mean()
    
    return pd.Series(data = d)

def avgEnergyConsumed(df, name, sizes):
    df.columns = ["Name","PKG","CPU", "GPU" , "DRAM?" , "Time (sec)"]
    d = {}
    for i in range(len(sizes)):
        d[str(sizes[i])] = df[df["Name"] == (name+str(sizes[i]))] ["CPU"].mean()
    
    return pd.Series(data = d)

# %%
def showGraphs(df):
    sns.set(rc={'figure.figsize':(15,8.27)})
    """
    plt.plot(df["Time (sec)"],".")
    plt.ylabel('time (ms)')
    plt.xlabel('Measurment NO')
    plt.show()
    
    plt.plot(df["CPU"],".")
    plt.ylabel('Energy (CPU) [J]')
    plt.xlabel('Measurement NO')
    plt.show()
    
    plt.plot(s, ".")
    plt.ylabel('Time (ms)')
    plt.xlabel('Array size')
    plt.xticks(rotation = 30)
    plt.show()
    """
    box = sns.boxplot(data=df, x='Name', y = df["CPU"])
    box.set_xticklabels(box.get_xticklabels(),rotation=30)

    plt.show()

    box = sns.boxplot(data=df, x='Name', y = 'Time (sec)')
    box.set_xticklabels(box.get_xticklabels(),rotation=30)

# %%
print("Example javasort Data (25k - 1m)")
sizes = [i*10000 for i in range(1,11)]
#print(sizes)
s = meanTimePrDataSize(dfMB, "JavaSort", sizes)
print(s)
showGraphs(dfMB)
# Out:
# Example javasort Data (25k - 1m)
# 10000             NaN
# 20000             NaN
# 30000             NaN
# 40000             NaN
# 50000      934.294097
# 60000             NaN
# 70000             NaN
# 80000             NaN
# 90000             NaN
# 100000    1005.773335
# dtype: float64

# %% [markdown]
#     Do a test on each size where we do 10 random files instead of one

# %%
dfRandomTests.columns = ["Name","PKG","CPU", "GPU" , "DRAM?" , "Time (sec)"]


dfRandomTests = dfRandomTests[dfRandomTests['CPU'] >= 0]
        
dfRandomTests.head()

#showGraphs(dfRandomTests)
plt.plot(dfRandomTests["CPU"], ".")
plt.ylim(-25,25)
# Out:
# (-25.0, 25.0)

# %%
sizes = [25000, 50000, 100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000, 900000, 1000000]
dfRandom1 = pd.DataFrame()
dfRandom2 = pd.DataFrame()
dfRandom3 = pd.DataFrame()
dfRandom4 = pd.DataFrame()
dfRandom5 = pd.DataFrame()
dfRandom6 = pd.DataFrame()
dfRandom7 = pd.DataFrame()
dfRandom8 = pd.DataFrame()
dfRandom9 = pd.DataFrame()
dfRandom10 = pd.DataFrame()


for i in range(len(sizes)):
    dfRandom1 = dfRandom1.append(dfRandomTests[dfRandomTests["Name"] == "random1-"+str(sizes[i])])
for i in range(len(sizes)):
    dfRandom2 = dfRandom2.append(dfRandomTests[dfRandomTests["Name"] == "random2-"+str(sizes[i])])
for i in range(len(sizes)):
    dfRandom3 = dfRandom3.append(dfRandomTests[dfRandomTests["Name"] == "random3-"+str(sizes[i])])
for i in range(len(sizes)):
    dfRandom4 = dfRandom4.append(dfRandomTests[dfRandomTests["Name"] == "random4-"+str(sizes[i])])
for i in range(len(sizes)):
    dfRandom5 = dfRandom5.append(dfRandomTests[dfRandomTests["Name"] == "random5-"+str(sizes[i])])
for i in range(len(sizes)):
    dfRandom6 = dfRandom6.append(dfRandomTests[dfRandomTests["Name"] == "random6-"+str(sizes[i])])
for i in range(len(sizes)):
    dfRandom7 = dfRandom7.append(dfRandomTests[dfRandomTests["Name"] == "random7-"+str(sizes[i])])
for i in range(len(sizes)):
    dfRandom8 = dfRandom8.append(dfRandomTests[dfRandomTests["Name"] == "random8-"+str(sizes[i])])
for i in range(len(sizes)):
    dfRandom9 = dfRandom9.append(dfRandomTests[dfRandomTests["Name"] == "random9-"+str(sizes[i])])
for i in range(len(sizes)):
    dfRandom10 = dfRandom10.append(dfRandomTests[dfRandomTests["Name"] == "random10-"+str(sizes[i])])


dfRandom2
d = [dfRandom1,dfRandom2,dfRandom3,dfRandom4,dfRandom5,dfRandom6,dfRandom7,dfRandom8,dfRandom9,dfRandom10]
# Out:
# C:\Users\mathi\AppData\Local\Temp\ipykernel_40068\3421779461.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfRandom1 = dfRandom1.append(dfRandomTests[dfRandomTests["Name"] == "random1-"+str(sizes[i])])
# C:\Users\mathi\AppData\Local\Temp\ipykernel_40068\3421779461.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfRandom1 = dfRandom1.append(dfRandomTests[dfRandomTests["Name"] == "random1-"+str(sizes[i])])
# C:\Users\mathi\AppData\Local\Temp\ipykernel_40068\3421779461.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfRandom1 = dfRandom1.append(dfRandomTests[dfRandomTests["Name"] == "random1-"+str(sizes[i])])
# ...

# %%
for i in range(len(d)):
    plt.plot(d[i]["CPU"],".")
plt.show()

# %%
plt.plot(meanTimePrDataSize(dfRandom1, "random1-", sizes),"-.")
plt.plot(meanTimePrDataSize(dfRandom2, "random2-", sizes),"-.")
plt.plot(meanTimePrDataSize(dfRandom3, "random3-", sizes),"-.")
plt.plot(meanTimePrDataSize(dfRandom4, "random4-", sizes),"-.")
plt.plot(meanTimePrDataSize(dfRandom5, "random5-", sizes),"-.")
plt.plot(meanTimePrDataSize(dfRandom6, "random6-", sizes),"-.")
plt.plot(meanTimePrDataSize(dfRandom7, "random7-", sizes),"-.")
plt.plot(meanTimePrDataSize(dfRandom8, "random8-", sizes),"-.")
plt.plot(meanTimePrDataSize(dfRandom9, "random9-", sizes),"-.")
plt.plot(meanTimePrDataSize(dfRandom10, "random10-", sizes),"-.")
plt.ylabel("Time (ms)")
plt.xlabel("Array size of int32")
plt.show()


for i in range(len(d)):
    plt.plot(meanTimePrDataSize(d[i], f"random{i}-", sizes), "-.")
plt.title("New graph")
plt.ylabel("Time (ms)")
plt.xlabel("Array size of int32")
plt.show()

# %%
plt.plot(avgEnergyConsumed(dfRandom1, "random1-", sizes),"-.")
plt.plot(avgEnergyConsumed(dfRandom2, "random2-", sizes),"-.")
plt.plot(avgEnergyConsumed(dfRandom3, "random3-", sizes),"-.")
plt.plot(avgEnergyConsumed(dfRandom4, "random4-", sizes),"-.")
plt.plot(avgEnergyConsumed(dfRandom5, "random5-", sizes),"-.")
plt.plot(avgEnergyConsumed(dfRandom6, "random6-", sizes),"-.")
plt.plot(avgEnergyConsumed(dfRandom7, "random7-", sizes),"-.")
plt.plot(avgEnergyConsumed(dfRandom8, "random8-", sizes),"-.")
plt.plot(avgEnergyConsumed(dfRandom9, "random9-", sizes),"-.")
plt.plot(avgEnergyConsumed(dfRandom10, "random10-", sizes),"-.")
plt.ylabel("CPU energy consumed (J)")
plt.xlabel("Array size of int32")
plt.ylim(0,25)
plt.show()

for i in range(len(d)):
    plt.plot(avgEnergyConsumed(d[i],f"random{i}-",sizes), "-.")
plt.ylabel("CPU energy consumed (J)")
plt.xlabel("Array size of int32")
plt.ylim(0,25)
plt.show()
